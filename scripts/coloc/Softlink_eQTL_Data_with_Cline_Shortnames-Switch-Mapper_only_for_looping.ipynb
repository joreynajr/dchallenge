# %%
import pandas as pd

# %%
import os

# %%
os.chdir('/mnt/BioHome/jreyna/jreyna/projects/dchallenge/')

# %%
mapper = pd.read_table('results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/eqtl.cline.mapper.study.tsv')

# %%
mapper.iloc[1].tolist()
# Out:
# ['results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/BLUEPRINT_eQTL/Monocyte.txt.gz',
#  'NCM',
#  'BLUEPRINT_eQTL',
#  'Yes']

# %%
new_dir = 'results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/shortnames/'
os.makedirs(new_dir, exist_ok=True)

# %%
mapper
# Out:
#                                             eqtl_file dice_shortname  \
# 0   results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_s...             CM
# 1   results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_s...            NCM
# 2   results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_s...            TFH
# 3   results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_s...            TH1
# 4   results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_s...           TH17
# 5   results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_s...            TH2
# 6   results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_s...         THSTAR
# 7   results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_s...        TREGMEM
# 8   results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_s...      TREGNAIVE
# 9   results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_s...             NT
# 10  results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_s...             CM
# 11  results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_s...            NCM
# 12  results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_s...            TFH
# ...

# %%
for i, sr in mapper.iterrows():
    shortname_basename = '{}.txt.gz'.format(sr.dice_shortname)
    shortname_path = os.path.join(new_dir, sr.study, shortname_basename)
    
    print(sr.eqtl_file)
    print(shortname_path)
    print()
#     if os.path.exists(shortname_path)
#     os.symlink()
# Out:
# results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/BLUEPRINT_eQTL/Monocyte.txt.gz
# results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/shortnames/BLUEPRINT_eQTL/CM.txt.gz
#
# results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/BLUEPRINT_eQTL/Monocyte.txt.gz
# results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/shortnames/BLUEPRINT_eQTL/NCM.txt.gz
#
# results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/BLUEPRINT_eQTL/T-cell.txt.gz
# results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/shortnames/BLUEPRINT_eQTL/TFH.txt.gz
#
# results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/BLUEPRINT_eQTL/T-cell.txt.gz
# results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/shortnames/BLUEPRINT_eQTL/TH1.txt.gz
#
# results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/BLUEPRINT_eQTL/T-cell.txt.gz
# results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/shortnames/BLUEPRINT_eQTL/TH17.txt.gz
#
# ...

# %%
sr
# Out:
# eqtl_file         results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_s...
# dice_shortname                                                   CM
# study                                                BLUEPRINT_eQTL
# will_analyze                                                    Yes
# Name: 0, dtype: object

# %%
shortname_path
# Out:
# 'results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/shortnames/GEUVADIS_sQTL/CM.txt.gz'

# %%
for fn in sorted(mapper.eqtl_file.unique()):
    print(fn)
# Out:
# results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/BLUEPRINT_eQTL/Monocyte.txt.gz
# results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/BLUEPRINT_eQTL/Neutrophil.txt.gz
# results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/BLUEPRINT_eQTL/T-cell.txt.gz
# results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/BLUEPRINT_sQTL/Monocyte.txt.gz
# results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/BLUEPRINT_sQTL/Neutrophil.txt.gz
# results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/BLUEPRINT_sQTL/T-cell.txt.gz
# results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/DGN_eQTL/DGN_eQTL.txt.gz
# results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/DGN_sQTL/DGN_sQTL.txt.gz
# results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/DICE_eQTL/B_NAIVE.txt.gz
# results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/DICE_eQTL/CD4_NAIVE.txt.gz
# results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/DICE_eQTL/CD4_N_STIM.txt.gz
# ...
