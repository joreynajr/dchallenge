# %%
import os 
import pandas as pd 
import glob
import json
os.chdir("/mnt/BioHome/jreyna/jreyna/projects/dchallenge/")
outdir = 'results/main/loop_analysis/Coloc_Approach/'

# %%
# loading and concat all the data
data = []
for fn in glob.glob('results/main/loop_analysis/Coloc_Approach/T1D_34012112_Gaulton/*/*/*/master.tsv'):
    
    dice_cline = fn.split('/')[5]
    study = fn.split('/')[6]
    eqtl_cline = fn.split('/')[7]
    
    df = pd.read_table(fn, header=0)
    df['dice_cline'] = dice_cline
    df['eqtl_cline'] = eqtl_cline
    df['study'] = study
    data.append(df)
    
data = pd.concat(data)
data.rename(columns={'5kb_gname': 'fivekb_gname'}, inplace=True)

# %%
new_order = [
 'sid',
 'rs_id',
 'gene_name',
 'dice_cline',
 'eqtl_cline',
 'study',
 'gene_id',
 'chrom',
 'snp_pos',
 'gene_start',
 'gene_end',
 'is_eqtl_pair',
 'is_coloc_pair',
 'is_closest_gene',
 'has_fithichip_loop',
 'nvar',
 'shape1',
 'shape2',
 'dist',
 'npval',
 'slope',
 'ppval',
 'bpval',
 'qval',
 'pp_H0_Coloc_Summary',
 'pp_H1_Coloc_Summary',
 'pp_H2_Coloc_Summary',
 'pp_H3_Coloc_Summary',
 'pp_H4_Coloc_Summary',
 'ref',
 'alt',
 'AC',
 'AF',
 'AN',
 'gwas_slope',
 'gwas_slope_se',
 'gwas_pval_nominal',
 'SampleSize']

# %%
data = data.loc[:, new_order]
data.drop_duplicates(subset=['sid', 'gene_name', 'dice_cline', 'eqtl_cline', 'study'], inplace=True)

# %%
master_fn = os.path.join(outdir, 'super_master.snp_gene_loop.analysis.tsv')
data.to_csv(master_fn, sep='\t', index=False, na_rep='nan')

# %% [raw]
# master_fn = os.path.join(outdir, 'super_master.snp_gene_loop.analysis.xlsx')
# xdata = data.sort_values(['rs_id', 'dice_cline', 'eqtl_cline', 'gene_name', 'study'])
# xdata.set_index(['rs_id', 'dice_cline', 'eqtl_cline', 'gene_name', 'study']).to_excel(master_fn, na_rep='nan')

# %% [markdown]
# ## eQTL Summary

# %% [markdown]
# I want to know how many eQTL's comparisons there are total

# %%
eqtl_only = data[(data.is_eqtl_pair == 1)]
print(eqtl_only.shape[0])
# Out:
# 97632

# %% [markdown]
# I want to know how many eQTL's have a loop

# %%
eqtl_loops_only = data[(data.is_eqtl_pair == 1) & (data.has_fithichip_loop == 1)]
print(eqtl_loops_only.shape[0])
# Out:
# 50

# %% [markdown]
# ## Colocalization Summary

# %% [markdown]
# I want to know how many colocalization comparisons there are total

# %%
coloc_only = data[(data.is_coloc_pair == 1)]
print(coloc_only.shape[0])
# Out:
# 251

# %% [markdown]
# I want to know how many colocalizations have a loop

# %%
coloc_loops_only = data[(data.is_coloc_pair == 1) & (data.has_fithichip_loop == 1)]
print(coloc_loops_only.shape[0])
# Out:
# 50

# %% [markdown]
# ## Breakdown of colocalized loops (SNP perspective)

# %% [markdown]
# I want to know the breakdown in terms of gene

# %%
coloc_loops_only.value_counts(subset=['sid', 'gene_name'])
# Out:
# sid          gene_name
# 21:43855067  UBASH3A        14
# 6:90976768   BACH2           7
# 16:11433103  RMI2            3
# 11:64107735  AP003774.1      3
# 12:9833628   RP11-75L1.1     3
# 11:64107477  AP003774.1      2
# 20:1610551   SIRPG           2
# 12:56401085  RPS26           2
# 16:11439303  RMI2            2
# 12:9147569   M6PR            1
# 15:79229199  CTSH            1
# 15:79231478  CTSH            1
# 16:11439679  RMI2            1
# 16:28599411  SULT1A2         1
# 16:28631530  SULT1A2         1
# 1:114426001  AP4B1           1
# 1:114447565  PTPN22          1
# 1:192537400  RGS1            1
# 21:43823736  TMPRSS3         1
# 21:43827765  TMPRSS3         1
# 11:64102948  AP003774.1      1
# dtype: int64

# %% [markdown]
# I want to know the breakdown in terms of cell line

# %%
coloc_loops_only.value_counts(subset=['gene_name', 'sid', 'dice_cline'])
# Out:
# gene_name    sid          dice_cline
# UBASH3A      21:43855067  TREGMEM       2
#                           TH2           2
#                           TH17          2
#                           TH1           2
#                           TFH           2
#                           THSTAR        2
# BACH2        6:90976768   TH17          1
# M6PR         12:9147569   TREGNAIVE     1
# CTSH         15:79231478  CM            1
#              15:79229199  NCM           1
# BACH2        6:90976768   TREGNAIVE     1
#                           TREGMEM       1
#                           THSTAR        1
#                           TH2           1
#                           TFH           1
#                           TH1           1
# RGS1         1:192537400  NCM           1
# AP4B1        1:114426001  NCM           1
# AP003774.1   11:64107735  TREGMEM       1
#                           TH2           1
#                           NB            1
# ...

# %% [markdown]
# ## Breakdown of colocalized loops (Gene perspective)

# %%
coloc_loops_only.groupby(['gene_name']).rs_id.unique()
# Out:
# gene_name
# AP003774.1        [rs663743, rs479777, rs574087]
# AP4B1                               [rs11102694]
# BACH2                               [rs72928038]
# CTSH                    [rs12592898, rs12148472]
# M6PR                                 [rs1805721]
# PTPN22                               [rs1217397]
# RGS1                                 [rs1323297]
# RMI2           [rs7187741, rs12149160, rs918738]
# RP11-75L1.1                          [rs3764021]
# RPS26                               [rs10876864]
# SIRPG                                [rs2281808]
# SULT1A2                 [rs62031607, rs55792032]
# TMPRSS3                   [rs9978717, rs9784215]
# UBASH3A                              [rs1893592]
# Name: rs_id, dtype: object

# %%
coloc_loops_only.groupby(['gene_name']).rs_id.nunique().sort_values()
# Out:
# gene_name
# AP4B1          1
# BACH2          1
# M6PR           1
# PTPN22         1
# RGS1           1
# RP11-75L1.1    1
# RPS26          1
# SIRPG          1
# UBASH3A        1
# CTSH           2
# SULT1A2        2
# TMPRSS3        2
# AP003774.1     3
# RMI2           3
# Name: rs_id, dtype: int64

# %%
coloc_loops_only.groupby(['gene_name']).rs_id.nunique().sort_values().shape
# Out:
# (14,)

# %%
coloc_loops_only
# Out:
#               sid       rs_id    gene_name dice_cline              eqtl_cline  \
# 2787  16:11433103   rs7187741         RMI2    TREGMEM                  T-cell
# 4910  21:43855067   rs1893592      UBASH3A    TREGMEM                  T-cell
# 6610   6:90976768  rs72928038        BACH2    TREGMEM                  T-cell
# 351   11:64107735    rs663743   AP003774.1    TREGMEM             TREG_MEMORY
# 620   12:56401085  rs10876864        RPS26    TREGMEM             TREG_MEMORY
# 1538  21:43855067   rs1893592      UBASH3A    TREGMEM             TREG_MEMORY
# 504    12:9147569   rs1805721         M6PR  TREGNAIVE              TREG_NAIVE
# 622   12:56401085  rs10876864        RPS26  TREGNAIVE              TREG_NAIVE
# 1549  21:43827765   rs9978717      TMPRSS3  TREGNAIVE              TREG_NAIVE
# 1574   12:9833628   rs3764021  RP11-75L1.1  TREGNAIVE                  T-cell
# 2787  16:11433103   rs7187741         RMI2  TREGNAIVE                  T-cell
# ...

# %%
summary = coloc_loops_only.loc[~coloc_loops_only.duplicated(subset=['study', 'eqtl_cline', 'sid', 'gene_id']), :]
summary = summary.groupby(['study', 'eqtl_cline']).apply(len)
summary = summary.reset_index()
summary.study = summary.study.str.replace('_eQTL', '')
summary = summary.sort_values(['study', 0, 'eqtl_cline'], ascending=[True, False, True])

# %%
summary
# Out:
#         study              eqtl_cline  0
# 1   BLUEPRINT                  T-cell  5
# 0   BLUEPRINT                Monocyte  2
# 15       DICE             TREG_MEMORY  3
# 16       DICE              TREG_NAIVE  3
# 2        DICE                 B_NAIVE  2
# 5        DICE               CD8_NAIVE  2
# 9        DICE  NONCLASSICAL_MONOCYTES  2
# 10       DICE                     TFH  2
# 11       DICE                     TH1  2
# 12       DICE                  TH1-17  2
# 13       DICE                    TH17  2
# 14       DICE                     TH2  2
# 3        DICE               CD4_NAIVE  1
# 4        DICE              CD4_N_STIM  1
# 6        DICE              CD8_N_STIM  1
# 7        DICE     CLASSICAL_MONOCYTES  1
# 8        DICE              NK_CD16POS  1

# %%
summary[0].describe()
# Out:
# count    17.0
# mean      2.0
# std       1.0
# min       1.0
# 25%       1.0
# 50%       2.0
# 75%       2.0
# max       5.0
# Name: 0, dtype: float64

# %% [raw]
# # Make a super hub

# %% [raw]
# super_hub = os.path.join(outdir, 'super_hub/')
# os.makedirs(super_hub, exist_ok=True)
# super_config = os.path.join(super_hub, 'hub.config.json')
# super_json = []
#
# # Make the SUPER hub
# for dy in glob.glob('results/main/loop_analysis/Coloc_Approach/T1D_34012112_Gaulton/*/*/*'):
#
#     gwas, dice_cline, eqtl, eqtl_cline = dy.split('/')[4:8]
#
#     if eqtl_cline != 'T-cell':
#         continue
#
#     print(dy)
#
#     # load the current json hub
#     hub_json = os.path.join(dy, 'hub.config.json')
#     hub_list = json.load(open(hub_json))
#
#     # make a link to the genes bed
#     gene_washu = os.path.join(dy, hub_list[0]['filename'])
#     gene_link = os.path.join(super_hub, hub_list[0]['filename'])
#     if not os.path.exists(gene_link):
#         os.link(gene_washu, gene_link)
#         os.link(gene_washu + '.tbi', gene_link + '.tbi')
#
#         hub_list[0]['filename'] = os.path.basename(gene_link)
#         super_json.append(hub_list[0])
#
#
#
#     # make a link to the snps bed
#     if dice_cline == 'TH17':
#         snp_washu = os.path.join(dy, hub_list[8]['filename'])
#         snp_link = os.path.join(super_hub, hub_list[8]['filename'])
#         if not os.path.exists(snp_link):
#             os.link(snp_washu, snp_link)
#             os.link(snp_washu + '.tbi', snp_link + '.tbi')
#
#             hub_list[8]['filename'] = os.path.basename(snp_link)
#             super_json.append(hub_list[8])
#
#
#
#
#     # make a link to the original
#     fithichip_washu = os.path.join(dy, hub_list[1]['filename'])
#     fithichip_link = os.path.join(super_hub, '{}.{}.{}.{}.FitHiChIP.interactions_FitHiC_Q0.01_WashU.bed.gz')
#     fithichip_link = fithichip_link.format(gwas, dice_cline, eqtl, eqtl_cline)
#
#     if not os.path.exists(fithichip_link):
#         os.link(fithichip_washu, fithichip_link)
#         os.link(fithichip_washu + '.tbi', fithichip_link + '.tbi')
#
#         hub_list[1]['filename'] = os.path.basename(fithichip_link)
#         hub_list[1]['name'] = '{} {} {} {} '.format(gwas, dice_cline, eqtl, eqtl_cline) + hub_list[1]['name']
#         super_json.append(hub_list[1])
#
#     #     # make a link to the SNP-Gene Pairs
#     #     sgloops_washu = os.path.join(dy, hub_list[7]['filename'])
#     #     sgloops_link = os.path.join(super_hub, '{}.{}.{}.{}.sgloops.interactions_FitHiC_Q0.01_WashU.bed.gz')
#     #     sgloops_link = sgloops_link.format(gwas, dice_cline, eqtl, eqtl_cline)
#
#     #     if not os.path.exists(sgloops_link):
#     #         os.link(sgloops_washu, sgloops_link)
#     #         os.link(sgloops_washu + '.tbi', sgloops_link + '.tbi')
#
#     #         hub_list[7]['filename'] = os.path.basename(sgloops_link)
#     #         hub_list[7]['name'] = '{} {} {} {} '.format(gwas, dice_cline, eqtl, eqtl_cline) + hub_list[7]['name']
#     #         super_json.append(hub_list[7])
#
#
# with open(super_config, 'w') as f:
#     f.write(json.dumps(super_json, indent=4))

# %% [raw]
# super_json
