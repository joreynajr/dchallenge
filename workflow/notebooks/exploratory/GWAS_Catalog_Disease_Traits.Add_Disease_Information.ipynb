# %%
import os
import pandas as pd
import requests

os.chdir('/mnt/BioHome/jreyna/jreyna/projects/dchallenge/')

# %%
gwas_meta = 'results/refs/gwas_catalog/gwas-catalog-v1.0.3-studies-r2022-02-02.tsv'
gwas_meta = pd.read_table(gwas_meta)

# %%
gwas_meta.head()
# Out:
#   DATE ADDED TO CATALOG  PUBMED ID   FIRST AUTHOR        DATE         JOURNAL  \
# 0            2017-08-04   27989323  Ahola-Olli AV  2016-12-13  Am J Hum Genet
# 1            2017-08-04   27989323  Ahola-Olli AV  2016-12-13  Am J Hum Genet
# 2            2017-08-04   27989323  Ahola-Olli AV  2016-12-13  Am J Hum Genet
# 3            2017-08-04   27989323  Ahola-Olli AV  2016-12-13  Am J Hum Genet
# 4            2017-08-04   27989323  Ahola-Olli AV  2016-12-13  Am J Hum Genet
#
#                                    LINK  \
# 0  www.ncbi.nlm.nih.gov/pubmed/27989323
# 1  www.ncbi.nlm.nih.gov/pubmed/27989323
# 2  www.ncbi.nlm.nih.gov/pubmed/27989323
# 3  www.ncbi.nlm.nih.gov/pubmed/27989323
# 4  www.ncbi.nlm.nih.gov/pubmed/27989323
#
#                                                STUDY  \
# 0  Genome-wide Association Study Identifies 27 Lo...
# 1  Genome-wide Association Study Identifies 27 Lo...
# 2  Genome-wide Association Study Identifies 27 Lo...
# 3  Genome-wide Association Study Identifies 27 Lo...
# 4  Genome-wide Association Study Identifies 27 Lo...
#
#                                DISEASE/TRAIT  \
# 0            beta-nerve growth factor levels
# 1  Vascular endothelial growth factor levels
# 2                               CTACK levels
# 3                             Eotaxin levels
# 4      Fibroblast growth factor basic levels
#
#                   INITIAL SAMPLE SIZE REPLICATION SAMPLE SIZE  ...  \
# 0  3,531 Finnish ancestry individuals                     NaN  ...
# 1  7,118 Finnish ancestry individuals                     NaN  ...
# 2  3,631 Finnish ancestry individuals                     NaN  ...
# 3  8,153 Finnish ancestry individuals                     NaN  ...
# 4  7,565 Finnish ancestry individuals                     NaN  ...
#
#                                      MAPPED_TRAIT  \
# 0            beta-nerve growth factor measurement
# 1  vascular endothelial growth factor measurement
# 2     chemokine (C-C motif) ligand 27 measurement
# 3                             eotaxin measurement
# 4      fibroblast growth factor basic measurement
#
#                        MAPPED_TRAIT_URI STUDY ACCESSION  \
# 0  http://www.ebi.ac.uk/efo/EFO_0008035      GCST004421
# 1  http://www.ebi.ac.uk/efo/EFO_0004762      GCST004422
# 2  http://www.ebi.ac.uk/efo/EFO_0008082      GCST004420
# 3  http://www.ebi.ac.uk/efo/EFO_0008122      GCST004460
# 4  http://www.ebi.ac.uk/efo/EFO_0008130      GCST004459
#
#           GENOTYPING TECHNOLOGY SUMMARY STATS LOCATION SUBMISSION DATE  \
# 0  Genome-wide genotyping array                    NaN             NaN
# 1  Genome-wide genotyping array                    NaN             NaN
# 2  Genome-wide genotyping array                    NaN             NaN
# 3  Genome-wide genotyping array                    NaN             NaN
# 4  Genome-wide genotyping array                    NaN             NaN
#
#    STATISTICAL MODEL  BACKGROUND TRAIT  MAPPED BACKGROUND TRAIT  \
# 0                NaN               NaN                      NaN
# 1                NaN               NaN                      NaN
# 2                NaN               NaN                      NaN
# 3                NaN               NaN                      NaN
# 4                NaN               NaN                      NaN
#
#    MAPPED BACKGROUND TRAIT URI
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Getting all the OLS Link ID/Disease Information

# %%
disease_info = []
for i in range(0, 37):
    
    split_fn = 'results/notebooks/gwas_catalog_disease_traits/processed/split.ols_id.{}.txt'
    split_fn = split_fn.format(i)
    split_info = open(split_fn).readlines()
    split_info = [x.strip().split() for x in split_info]
    disease_info.extend(split_info)

# %%
disease_index_dict = {k:v for k,v in disease_info}

# %%
len(disease_index_dict.keys())
# Out:
# 3687

# %% [markdown]
# ## Add the final disease_or_disorder column to the gwas_meta file

# %%
dd_list = []
for i, uris in enumerate(gwas_meta['MAPPED_TRAIT_URI']):
    
    # default dd will be other
    dd_list.append('other')
    
    # assign disease or disorder when possible
    if type(uris) == str:
        for uri in uris.split(','):
            uri = uri.strip()
            
            if uri in disease_index_dict:
                
                if disease_index_dict[uri] == 'disease':
                    dd_list[i] = ('disease')
                    break

                elif disease_index_dict[uri] == 'disorder':
                    dd_list[i] = ('disorder')

# %%
disease_index_dict['http://www.ebi.ac.uk/efo/EFO_0008035']
# Out:
# 'disease'

# %%
if -1:
    print('hi')
# Out:
# hi

# %%
if 0:
    print('hi')

# %%
gwas_meta['MAPPED_TRAIT_URI']
# Out:
# 0        http://www.ebi.ac.uk/efo/EFO_0008035
# 1        http://www.ebi.ac.uk/efo/EFO_0004762
# 2        http://www.ebi.ac.uk/efo/EFO_0008082
# 3        http://www.ebi.ac.uk/efo/EFO_0008122
# 4        http://www.ebi.ac.uk/efo/EFO_0008130
#                          ...
# 33157    http://www.ebi.ac.uk/efo/EFO_0007990
# 33158    http://www.ebi.ac.uk/efo/EFO_0007985
# 33159    http://www.ebi.ac.uk/efo/EFO_0007984
# 33160    http://www.ebi.ac.uk/efo/EFO_0004309
# 33161    http://www.ebi.ac.uk/efo/EFO_0004305
# Name: MAPPED_TRAIT_URI, Length: 33162, dtype: object

# %%
gwas_meta['disease_or_disorder'] = dd_list

# %%
gwas_meta[gwas_meta.disease_or_disorder.isin(['disease', 'disorder'])]
# Out:
#       DATE ADDED TO CATALOG  PUBMED ID   FIRST AUTHOR        DATE  \
# 0                2017-08-04   27989323  Ahola-Olli AV  2016-12-13
# 1                2017-08-04   27989323  Ahola-Olli AV  2016-12-13
# 2                2017-08-04   27989323  Ahola-Olli AV  2016-12-13
# 3                2017-08-04   27989323  Ahola-Olli AV  2016-12-13
# 4                2017-08-04   27989323  Ahola-Olli AV  2016-12-13
# ...                     ...        ...            ...         ...
# 33157            2020-09-18   32888494     Vuckovic D  2020-09-01
# 33158            2020-09-18   32888494     Vuckovic D  2020-09-01
# 33159            2020-09-18   32888494     Vuckovic D  2020-09-01
# 33160            2020-09-18   32888494     Vuckovic D  2020-09-01
# 33161            2020-09-18   32888494     Vuckovic D  2020-09-01
#
#               JOURNAL                                  LINK  \
# 0      Am J Hum Genet  www.ncbi.nlm.nih.gov/pubmed/27989323
# 1      Am J Hum Genet  www.ncbi.nlm.nih.gov/pubmed/27989323
# 2      Am J Hum Genet  www.ncbi.nlm.nih.gov/pubmed/27989323
# 3      Am J Hum Genet  www.ncbi.nlm.nih.gov/pubmed/27989323
# 4      Am J Hum Genet  www.ncbi.nlm.nih.gov/pubmed/27989323
# ...               ...                                   ...
# 33157            Cell  www.ncbi.nlm.nih.gov/pubmed/32888494
# 33158            Cell  www.ncbi.nlm.nih.gov/pubmed/32888494
# 33159            Cell  www.ncbi.nlm.nih.gov/pubmed/32888494
# 33160            Cell  www.ncbi.nlm.nih.gov/pubmed/32888494
# 33161            Cell  www.ncbi.nlm.nih.gov/pubmed/32888494
#
#                                                    STUDY  \
# 0      Genome-wide Association Study Identifies 27 Lo...
# 1      Genome-wide Association Study Identifies 27 Lo...
# 2      Genome-wide Association Study Identifies 27 Lo...
# 3      Genome-wide Association Study Identifies 27 Lo...
# 4      Genome-wide Association Study Identifies 27 Lo...
# ...                                                  ...
# 33157  The Polygenic and Monogenic Basis of Blood Tra...
# 33158  The Polygenic and Monogenic Basis of Blood Tra...
# 33159  The Polygenic and Monogenic Basis of Blood Tra...
# 33160  The Polygenic and Monogenic Basis of Blood Tra...
# 33161  The Polygenic and Monogenic Basis of Blood Tra...
#
#                                    DISEASE/TRAIT  \
# 0                beta-nerve growth factor levels
# 1      Vascular endothelial growth factor levels
# 2                                   CTACK levels
# 3                                 Eotaxin levels
# 4          Fibroblast growth factor basic levels
# ...                                          ...
# 33157       Neutrophil percentage of white cells
# 33158                               Plateletcrit
# 33159                Platelet distribution width
# 33160                             Platelet count
# 33161                       Red blood cell count
#
#                       INITIAL SAMPLE SIZE REPLICATION SAMPLE SIZE  ...  \
# 0      3,531 Finnish ancestry individuals                     NaN  ...
# 1      7,118 Finnish ancestry individuals                     NaN  ...
# 2      3,631 Finnish ancestry individuals                     NaN  ...
# 3      8,153 Finnish ancestry individuals                     NaN  ...
# 4      7,565 Finnish ancestry individuals                     NaN  ...
# ...                                   ...                     ...  ...
# 33157         408,112 British individuals                     NaN  ...
# 33158         408,112 British individuals                     NaN  ...
# 33159         408,112 British individuals                     NaN  ...
# 33160         408,112 British individuals                     NaN  ...
# 33161         408,112 British individuals                     NaN  ...
#
#                            MAPPED_TRAIT_URI  STUDY ACCESSION  \
# 0      http://www.ebi.ac.uk/efo/EFO_0008035       GCST004421
# 1      http://www.ebi.ac.uk/efo/EFO_0004762       GCST004422
# 2      http://www.ebi.ac.uk/efo/EFO_0008082       GCST004420
# 3      http://www.ebi.ac.uk/efo/EFO_0008122       GCST004460
# 4      http://www.ebi.ac.uk/efo/EFO_0008130       GCST004459
# ...                                     ...              ...
# 33157  http://www.ebi.ac.uk/efo/EFO_0007990     GCST90002399
# 33158  http://www.ebi.ac.uk/efo/EFO_0007985     GCST90002400
# 33159  http://www.ebi.ac.uk/efo/EFO_0007984     GCST90002401
# 33160  http://www.ebi.ac.uk/efo/EFO_0004309     GCST90002402
# 33161  http://www.ebi.ac.uk/efo/EFO_0004305     GCST90002403
#
#               GENOTYPING TECHNOLOGY SUMMARY STATS LOCATION SUBMISSION DATE  \
# 0      Genome-wide genotyping array                    NaN             NaN
# 1      Genome-wide genotyping array                    NaN             NaN
# 2      Genome-wide genotyping array                    NaN             NaN
# 3      Genome-wide genotyping array                    NaN             NaN
# 4      Genome-wide genotyping array                    NaN             NaN
# ...                             ...                    ...             ...
# 33157  Genome-wide genotyping array                    NaN             NaN
# 33158  Genome-wide genotyping array                    NaN             NaN
# 33159  Genome-wide genotyping array                    NaN             NaN
# 33160  Genome-wide genotyping array                    NaN             NaN
# 33161  Genome-wide genotyping array                    NaN             NaN
#
#       STATISTICAL MODEL  BACKGROUND TRAIT  MAPPED BACKGROUND TRAIT  \
# 0                   NaN               NaN                      NaN
# 1                   NaN               NaN                      NaN
# 2                   NaN               NaN                      NaN
# 3                   NaN               NaN                      NaN
# 4                   NaN               NaN                      NaN
# ...                 ...               ...                      ...
# 33157               NaN               NaN                      NaN
# 33158               NaN               NaN                      NaN
# 33159               NaN               NaN                      NaN
# 33160               NaN               NaN                      NaN
# 33161               NaN               NaN                      NaN
#
#        MAPPED BACKGROUND TRAIT URI  disease_or_disorder
# 0                              NaN              disease
# 1                              NaN              disease
# 2                              NaN              disease
# 3                              NaN              disease
# 4                              NaN              disease
# ...                            ...                  ...
# 33157                          NaN              disease
# 33158                          NaN              disease
# 33159                          NaN              disease
# 33160                          NaN              disease
# 33161                          NaN              disease
#
# [33036 rows x 23 columns]

# %%
new_gwas_fn = 'results/refs/gwas_catalog/gwas-catalog-v1.0.3-studies-r2022-02-02.withDDColumn.tsv'
gwas_meta.to_csv(new_gwas_fn, sep='\t', index=False)
