# %%
import os 
import subprocess as sp
import pandas as pd
import glob 
import seaborn as sns 
import matplotlib.pyplot as plt 

os.chdir('/mnt/BioHome/jreyna/jreyna/projects/dchallenge/')

# %% [markdown]
# ## Number of eQTL before filtering (eQTL Catalog)

# %%
before_data = []
before_glob = 'results/main/eqtl/*/ge/*_ge_*.all.prefilter.num_eqtls.txt'
before_glob = glob.glob(before_glob)

# %%
before_data = []
for fn in before_glob:
    with open(fn) as fr:
        
        eqtl, ge = os.path.basename(fn).split('_ge_')
        ge = ge.split('.')[0]
        
        num_eqtls = int(fr.read().strip())
        
        before_data.append([eqtl, ge, num_eqtls])

# %%
before_df = pd.DataFrame(before_data)
before_df.columns = ['eqtl', 'ge', 'num_eqtls_pre']

# %% [markdown]
# ## Number of eQTL post filtering (eQTL Catalog)

# %%
post_data = []
post_glob = 'results/main/eqtl/*/ge/*_ge_*.all.postfilter.num_eqtls.txt'
post_glob = glob.glob(post_glob)

# %%
post_data = []
for fn in post_glob:
    with open(fn) as fr:
        
        eqtl, ge = os.path.basename(fn).split('_ge_')
        ge = ge.split('.')[0]
        
        num_eqtls = int(fr.read().strip())
        
        post_data.append([eqtl, ge, num_eqtls])

# %%
post_df = pd.DataFrame(post_data)
post_df.columns = ['eqtl', 'ge', 'num_eqtls_post']

# %%
post_df
# Out:
#                 eqtl                    ge  num_eqtls_post
# 0               GTEx    brain_hypothalamus          423929
# 1               GTEx         brain_putamen          559636
# 2               GTEx       artery_coronary          551959
# 3               GTEx         kidney_cortex          123311
# 4               GTEx  heart_left_ventricle         1091506
# ..               ...                   ...             ...
# 72    Schmiedel_2018         NK-cell_naive          472002
# 73           GENCORD                   LCL          823148
# 74           GENCORD            fibroblast          575290
# 75           GENCORD                T-cell          716949
# 76  van_de_Bunt_2015      pancreatic_islet          178434
#
# [77 rows x 3 columns]

# %% [markdown]
# ## Number of eQTL post filtering (Mu et al., 2021)

# %%
mu_data = []
mu_glob = 'results/main/2021_Nikhil_eQTL/Data/eqtl_sqtl_summ_stats/*_eQTL/*.input.txt'
mu_glob = glob.glob(mu_glob)

# %%
mu_data = []
for fn in mu_glob:
    with open(fn) as fr:
                
        eqtl, ge = fn.split('/')[-2:]
        eqtl = eqtl.split('_')[0]
        ge = ge.split('.')[0]
       
        num_eqtls = len(fr.readlines())
        
        mu_data.append([eqtl, ge, num_eqtls])

# %%
mu_df = pd.DataFrame(mu_data)
mu_df.columns = ['eqtl', 'ge', 'num_eqtls_mu']

# initializing with the original name 
cell_dict = {k:v for k, v in zip(mu_df['ge'], mu_df['ge'])}

# change the cell line name for those cell lines I care about 
replace_dict = {'Neutrophil': 'neutrophil',
             'Monocyte': 'monocyte',
             'TREG_NAIVE': 'Treg_naive',
             'TREG_MEMORY': 'Treg_memory',
             'B_NAIVE': 'B-cell_naive',
             'TFH': 'Tfh_memory',
             'TH1-17': 'Th1-17_memory',
             'CD4_N_STIM': 'CD4_N_STIM',
             'NK_CD16POS': 'NK-cell_naive',
             'NONCLASSICAL_MONOCYTES': 'monocyte_CD16_naive',
             'CD8_NAIVE': 'CD8_T-cell_naive',
             'TH17': 'Th17_memory',
             'CD8_N_STIM': 'CD8_T-cell_anti-CD3-CD28',
             'CLASSICAL_MONOCYTES': 'monocyte_naive',
             'CD4_NAIVE': 'CD4_T-cell_naive	',
             'TH1': 'Th1_memory',
             'TH2': 'Th2_memory'}
cell_dict.update(replace_dict)
mu_df['ge'] = mu_df['ge'].map(cell_dict, )

# %%
# replace the eqtl source name when necessary
eqtl_sources = {k: v for k, v in zip(mu_df['eqtl'], mu_df['eqtl'])}
eqtl_sources['DICE'] = 'Schmiedel_2018'
mu_df['eqtl'] = mu_df['eqtl'].map(eqtl_sources)

# %%
mu_df.head()
# Out:
#              eqtl            ge  num_eqtls_mu
# 0        GEUVADIS           CEU          9294
# 1        GEUVADIS           YRI          2474
# 2  Schmiedel_2018    Treg_naive          2106
# 3  Schmiedel_2018   Treg_memory          1972
# 4  Schmiedel_2018  B-cell_naive          1827

# %% [markdown]
# ## Compare the eQTL Catalog before and after FDR filtering

# %%
all_df = pd.merge(before_df, post_df, on=['eqtl', 'ge'], how='outer')
all_df['%Post'] = all_df['num_eqtls_post'] / all_df['num_eqtls_pre'] * 100

# %%
pd.set_option('display.max_rows', 100) 
display(all_df)
pd.set_option('display.max_rows', 20)
# Out:
#                 eqtl                               ge  num_eqtls_pre  \
# 0               GTEx                          stomach      164513595
# 1               GTEx                    brain_caudate      175054708
# 2               GTEx                           muscle      134303457
# 3               GTEx                brain_spinal_cord      168668568
# 4               GTEx                 brain_cerebellum      167769402
# 5               GTEx                  artery_coronary      162448099
# 6               GTEx                           breast      172228883
# 7               GTEx                            ovary      163412345
# 8               GTEx                 colon_transverse      168613256
# 9               GTEx                           vagina      167971169
# 10              GTEx             heart_left_ventricle      154646246
# 11              GTEx               brain_hypothalamus      177038437
# 12              GTEx                           uterus      163759505
# 13              GTEx                            liver      145722181
# 14              GTEx                   brain_amygdala      172424838
# 15              GTEx                    colon_sigmoid      163844032
# 16              GTEx                            blood      117815659
# 17              GTEx                 skin_sun_exposed      163322320
# 18              GTEx      brain_cerebellar_hemisphere      162510726
# 19              GTEx                    adrenal_gland      159291457
# 20              GTEx             esophagus_muscularis      158515838
# 21              GTEx                     brain_cortex      172395548
# 22              GTEx                        pituitary      175697076
# 23              GTEx                       fibroblast      136548606
# 24              GTEx                              LCL      134305450
# 25              GTEx           heart_atrial_appendage      157561336
# 26              GTEx          brain_nucleus_accumbens      174567689
# 27              GTEx                    esophagus_gej      159952566
# 28              GTEx           brain_substantia_nigra      169669525
# 29              GTEx                             lung      170356939
# 30              GTEx                     artery_aorta      155343364
# 31              GTEx                           testis      217040861
# 32              GTEx                         pancreas      134927983
# 33              GTEx                    kidney_cortex      166674968
# 34              GTEx                 esophagus_mucosa      151397457
# 35              GTEx                    artery_tibial      149696926
# 36              GTEx  brain_anterior_cingulate_cortex      169679980
# 37              GTEx             brain_frontal_cortex      168439512
# 38              GTEx                         prostate      178134566
# 39              GTEx                    brain_putamen      170637762
# 40              GTEx                 adipose_visceral      163519153
# 41              GTEx             skin_not_sun_exposed      163743853
# 42              GTEx             minor_salivary_gland      160186457
# 43              GTEx             adipose_subcutaneous      161593005
# 44              GTEx                brain_hippocampus      177968032
# 45              GTEx                           spleen      160676960
# 46              GTEx                     nerve_tibial      167790232
# 47              GTEx                          thyroid      171339394
# 48              GTEx                  small_intestine      172495178
# 49        Lepik_2017                            blood      103124065
# 50        Quach_2016                    monocyte_R848      168940282
# 51        Quach_2016                monocyte_Pam3CSK4      171429490
# 52        Quach_2016                     monocyte_IAV      188522612
# 53        Quach_2016                   monocyte_naive      177145991
# 54        Quach_2016                     monocyte_LPS      169199423
# 55         BLUEPRINT                         monocyte      107504217
# 56         BLUEPRINT                           T-cell      114006812
# 57         BLUEPRINT                       neutrophil       86606708
# 58    Schmiedel_2018                      Treg_memory      155297785
# 59    Schmiedel_2018                   monocyte_naive      138656372
# 60    Schmiedel_2018                       Treg_naive      156779364
# 61    Schmiedel_2018              monocyte_CD16_naive      139733495
# 62    Schmiedel_2018                       Tfh_memory      155294143
# 63    Schmiedel_2018                    NK-cell_naive      156385911
# 64    Schmiedel_2018                 CD8_T-cell_naive      155723260
# 65    Schmiedel_2018                      Th17_memory      151190959
# 66    Schmiedel_2018                     B-cell_naive      154773799
# 67    Schmiedel_2018                       Th1_memory      153424768
# 68    Schmiedel_2018                 CD4_T-cell_naive      154286630
# 69    Schmiedel_2018                    Th1-17_memory      150672748
# 70    Schmiedel_2018         CD4_T-cell_anti-CD3-CD28      141385943
# 71    Schmiedel_2018                       Th2_memory      154397233
# 72    Schmiedel_2018         CD8_T-cell_anti-CD3-CD28      141347873
# 73           GENCORD                              LCL      142098342
# 74           GENCORD                       fibroblast      135886402
# 75           GENCORD                           T-cell      155301586
# 76  van_de_Bunt_2015                 pancreatic_islet      180559672
#
#     num_eqtls_post     %Post
# 0           869131  0.528303
# 1           696488  0.397869
# 2          1672825  1.245556
# 3           396491  0.235071
# 4          1347204  0.803009
# 5           551959  0.339776
# 6          1122669  0.651847
# 7           449356  0.274983
# 8          1147373  0.680476
# 9           303041  0.180413
# 10         1091506  0.705808
# 11          423929  0.239456
# 12          301774  0.184279
# 13          505211  0.346695
# 14          311365  0.180580
# 15          996647  0.608290
# 16         1515737  1.286533
# 17         2017018  1.234992
# 18         1009934  0.621457
# 19          782838  0.491450
# 20         1697245  1.070710
# 21          829362  0.481081
# 22          894226  0.508959
# 23         1870482  1.369829
# 24          431998  0.321653
# 25         1154695  0.732854
# 26          694671  0.397938
# 27         1093510  0.683646
# 28          260585  0.153584
# 29         1521353  0.893038
# 30         1388992  0.894143
# 31         2218588  1.022198
# 32         1063897  0.788492
# 33          123311  0.073983
# 34         1706880  1.127417
# 35         1903782  1.271758
# 36          458124  0.269993
# 37          548608  0.325700
# 38          633675  0.355728
# 39          559636  0.327967
# 40         1299706  0.794834
# 41         1664368  1.016446
# 42          388546  0.242559
# 43         1946741  1.204719
# 44          392064  0.220300
# 45          999133  0.621827
# 46         2458457  1.465197
# 47         2559921  1.494064
# 48          546703  0.316938
# 49         2946020  2.856773
# 50         1047996  0.620335
# 51         1177094  0.686634
# 52         1049180  0.556527
# 53         1293710  0.730307
# 54         1101435  0.650969
# 55         2213353  2.058852
# 56         1818085  1.594716
# 57         1838013  2.122252
# 58          588584  0.379003
# 59          643412  0.464033
# 60          623104  0.397440
# 61          614987  0.440114
# 62          603596  0.388679
# 63          472002  0.301819
# 64          706670  0.453799
# 65          701417  0.463928
# 66          633355  0.409213
# 67          513914  0.334962
# 68          669339  0.433828
# 69          636433  0.422394
# 70          518618  0.366810
# 71          615587  0.398703
# 72          510059  0.360854
# 73          823148  0.579281
# 74          575290  0.423361
# 75          716949  0.461650
# 76          178434  0.098823

# %%
summary = all_df.drop('%Post', axis=1).describe()

# %%
summary
# Out:
#        num_eqtls_pre  num_eqtls_post
# count   7.700000e+01    7.700000e+01
# mean    1.578687e+08    9.954745e+05
# std     1.958584e+07    6.194735e+05
# min     8.660671e+07    1.233110e+05
# 25%     1.513975e+08    5.486080e+05
# 50%     1.615930e+08    7.828380e+05
# 75%     1.696695e+08    1.299706e+06
# max     2.170409e+08    2.946020e+06

# %% [markdown]
# ## Add Mu et al eQTL's to compare

# %%
all_plus_mu = all_df.merge(mu_df, on=['eqtl', 'ge'])

# %%
all_plus_mu['%Mu'] = all_plus_mu['num_eqtls_mu'] / all_plus_mu['num_eqtls_pre'] * 100

# %%
all_plus_mu
# Out:
#               eqtl                        ge  num_eqtls_pre  num_eqtls_post  \
# 0        BLUEPRINT                  monocyte      107504217         2213353
# 1        BLUEPRINT                    T-cell      114006812         1818085
# 2        BLUEPRINT                neutrophil       86606708         1838013
# 3   Schmiedel_2018               Treg_memory      155297785          588584
# 4   Schmiedel_2018            monocyte_naive      138656372          643412
# 5   Schmiedel_2018                Treg_naive      156779364          623104
# 6   Schmiedel_2018       monocyte_CD16_naive      139733495          614987
# 7   Schmiedel_2018                Tfh_memory      155294143          603596
# 8   Schmiedel_2018             NK-cell_naive      156385911          472002
# 9   Schmiedel_2018          CD8_T-cell_naive      155723260          706670
# 10  Schmiedel_2018               Th17_memory      151190959          701417
# 11  Schmiedel_2018              B-cell_naive      154773799          633355
# 12  Schmiedel_2018                Th1_memory      153424768          513914
# 13  Schmiedel_2018             Th1-17_memory      150672748          636433
# 14  Schmiedel_2018                Th2_memory      154397233          615587
# 15  Schmiedel_2018  CD8_T-cell_anti-CD3-CD28      141347873          510059
#
#        %Post  num_eqtls_mu       %Mu
# 0   2.058852          7717  0.007178
# 1   1.594716          7212  0.006326
# 2   2.122252          6400  0.007390
# 3   0.379003          1972  0.001270
# 4   0.464033          2253  0.001625
# 5   0.397440          2106  0.001343
# 6   0.440114          2105  0.001506
# 7   0.388679          2054  0.001323
# 8   0.301819          1883  0.001204
# 9   0.453799          2374  0.001524
# 10  0.463928          2521  0.001667
# 11  0.409213          1827  0.001180
# 12  0.334962          1903  0.001240
# 13  0.422394          2188  0.001452
# 14  0.398703          2161  0.001400
# 15  0.360854          2002  0.001416

# %% [markdown]
# What is causing the difference between the Mu et al 2021 data and the eQTL Catalogue? In the next statements I'm considering BLUEPRINT monocytes. The eQTL Catalog we see 107,504,217 eQTL tests whereas for Mu et al we see 7,717 tests. Even after filtering the eQTL Catalogue for FDR < 0.05 there are 2,213,353 eQTL tests.
#
# #### Questions
# - Difference in the FDR?
#
# #### Answers
# - Mu et al uses GRCh37, eQTL catalogue uses GRCh38
# - Mu et al uses GENCODE v19, eQTL catalog uses GENCODE v30
# - The Additional File 1 Table 8 says that the Zenodo files are: "List of significant eQTLs and sQTLs"
