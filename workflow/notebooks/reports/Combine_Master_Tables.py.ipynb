# %%
import os 
import dask.dataframe as dd
import pandas as pd 
pd.get_option("display.max_columns", None)
pd.options.display.max_columns = None
import numpy as np
import glob
import json
from IPython.display import HTML
os.chdir("/mnt/BioHome/jreyna/jreyna/projects/dchallenge/")
outdir = 'results/main/sgls/combined/'
os.makedirs(outdir, exist_ok=True)

# %%
major_cols = [
 'gwas_source',
 'ge_source',
 'loop_source',
 'sid',
 'rsid',
 'geneid',
 'gene_name',
 'chrom',
 'snp_pos',
 'tss_start',
 'tss_end',
 'is_eqtl_pair',
 'is_coloc_pair',
 'is_closest_gene',
 'has_fithichip_loop',
 'eqtl_pval',
 'eqtl_fdr',
 'dist',
 'ppH4',
 'gene_start',
 'gene_end',
 'ref',
 'alt',
 'AC',
 'AF',
 'AN',
 'gwas_pval',
 'gene_strand',
 'eqtl_source']

# %% [markdown]
# ## Loading GENCODE information

# %%
gene_info = pd.read_table('results/refs/gencode/v30/gencode.v30.annotation.bed', header=None)
gene_dict = pd.concat([gene_info.iloc[:, [5,6]], gene_info.iloc[:, [6,5]]])
#{sr[5]: sr[6] for i, sr in gene_info.iterrows()}
gene_dict.drop_duplicates(inplace=True)
gene_dict.set_index(5, inplace=True)
gene_dict = gene_dict.squeeze()
gene_dict = gene_dict.to_dict()

# %% [markdown]
# ## Checking the samplesheet

# %%
samplesheet = pd.read_table('config/sgl.samplesheet.tsv.v2')
template = 'results/main/sgls/T1D_34012112_Gaulton/{}/{}'
output_exists = []
for i, sr in samplesheet.iterrows():
    test = os.path.exists(template.format(sr.eqtl_db, sr.eqtl_origin, sr.loop_origin))
    output_exists.append(test)
samplesheet['analyzed'] = output_exists

# %%
samplesheet.sort_values(['analyzed', 'eqtl_db', 'eqtl_origin', 'loop_origin'], \
                       ascending=[False, True, True, True], inplace=True)

samplesheet.reset_index(drop=True, inplace=True)
samplesheet.columns = ['GWAS Source', 'eQTL Source', 'GE Source', 'Loop Source', 'Analyzed?']

# %%
samplesheet
# Out:
#                   GWAS Source     eQTL Source                 GE Source  \
# 0        T1D_34012112_Gaulton      Quach_2016              monocyte_IAV
# 1   T1D_34594039_GCST90018925      Quach_2016              monocyte_IAV
# 2                T1D_32005708      Quach_2016              monocyte_IAV
# 3                T1D_25751624      Quach_2016              monocyte_IAV
# 4        T1D_34012112_Gaulton      Quach_2016         monocyte_Pam3CSK4
# 5   T1D_34594039_GCST90018925      Quach_2016         monocyte_Pam3CSK4
# 6                T1D_32005708      Quach_2016         monocyte_Pam3CSK4
# 7                T1D_25751624      Quach_2016         monocyte_Pam3CSK4
# 8        T1D_34012112_Gaulton      Quach_2016             monocyte_R848
# 9   T1D_34594039_GCST90018925      Quach_2016             monocyte_R848
# 10               T1D_32005708      Quach_2016             monocyte_R848
# 11               T1D_25751624      Quach_2016             monocyte_R848
# 12       T1D_34012112_Gaulton  Schmiedel_2018              B-cell_naive
# 13  T1D_34594039_GCST90018925  Schmiedel_2018              B-cell_naive
# 14               T1D_32005708  Schmiedel_2018              B-cell_naive
# 15               T1D_25751624  Schmiedel_2018              B-cell_naive
# 16       T1D_34012112_Gaulton  Schmiedel_2018  CD4_T-cell_anti-CD3-CD28
# 17  T1D_34594039_GCST90018925  Schmiedel_2018  CD4_T-cell_anti-CD3-CD28
# 18               T1D_32005708  Schmiedel_2018  CD4_T-cell_anti-CD3-CD28
# 19               T1D_25751624  Schmiedel_2018  CD4_T-cell_anti-CD3-CD28
# 20       T1D_34012112_Gaulton  Schmiedel_2018          CD4_T-cell_naive
# 21  T1D_34594039_GCST90018925  Schmiedel_2018          CD4_T-cell_naive
# 22               T1D_32005708  Schmiedel_2018          CD4_T-cell_naive
# 23               T1D_25751624  Schmiedel_2018          CD4_T-cell_naive
# 24       T1D_34012112_Gaulton  Schmiedel_2018  CD8_T-cell_anti-CD3-CD28
# 25  T1D_34594039_GCST90018925  Schmiedel_2018  CD8_T-cell_anti-CD3-CD28
# 26               T1D_32005708  Schmiedel_2018  CD8_T-cell_anti-CD3-CD28
# 27               T1D_25751624  Schmiedel_2018  CD8_T-cell_anti-CD3-CD28
# 28       T1D_34012112_Gaulton  Schmiedel_2018          CD8_T-cell_naive
# 29  T1D_34594039_GCST90018925  Schmiedel_2018          CD8_T-cell_naive
# 30               T1D_32005708  Schmiedel_2018          CD8_T-cell_naive
# 31               T1D_25751624  Schmiedel_2018          CD8_T-cell_naive
# 32       T1D_34012112_Gaulton  Schmiedel_2018             NK-cell_naive
# 33  T1D_34594039_GCST90018925  Schmiedel_2018             NK-cell_naive
# 34               T1D_32005708  Schmiedel_2018             NK-cell_naive
# 35               T1D_25751624  Schmiedel_2018             NK-cell_naive
# 36       T1D_34012112_Gaulton      Quach_2016              monocyte_LPS
# 37  T1D_34594039_GCST90018925      Quach_2016              monocyte_LPS
# 38               T1D_32005708      Quach_2016              monocyte_LPS
# 39               T1D_25751624      Quach_2016              monocyte_LPS
# 40       T1D_34012112_Gaulton  Schmiedel_2018       monocyte_CD16_naive
# 41  T1D_34594039_GCST90018925  Schmiedel_2018       monocyte_CD16_naive
# 42               T1D_32005708  Schmiedel_2018       monocyte_CD16_naive
# 43               T1D_25751624  Schmiedel_2018       monocyte_CD16_naive
# 44       T1D_34012112_Gaulton  Schmiedel_2018            monocyte_naive
# 45  T1D_34594039_GCST90018925  Schmiedel_2018            monocyte_naive
# 46               T1D_32005708  Schmiedel_2018            monocyte_naive
# 47               T1D_25751624  Schmiedel_2018            monocyte_naive
#
#          Loop Source  Analyzed?
# 0     monocyte_naive       True
# 1     monocyte_naive       True
# 2     monocyte_naive       True
# 3     monocyte_naive       True
# 4     monocyte_naive       True
# 5     monocyte_naive       True
# 6     monocyte_naive       True
# 7     monocyte_naive       True
# 8     monocyte_naive       True
# 9     monocyte_naive       True
# 10    monocyte_naive       True
# 11    monocyte_naive       True
# 12      B-cell_naive       True
# 13      B-cell_naive       True
# 14      B-cell_naive       True
# 15      B-cell_naive       True
# 16  CD4_T-cell_naive       True
# 17  CD4_T-cell_naive       True
# 18  CD4_T-cell_naive       True
# 19  CD4_T-cell_naive       True
# 20  CD4_T-cell_naive       True
# 21  CD4_T-cell_naive       True
# 22  CD4_T-cell_naive       True
# 23  CD4_T-cell_naive       True
# 24  CD8_T-cell_naive       True
# 25  CD8_T-cell_naive       True
# 26  CD8_T-cell_naive       True
# 27  CD8_T-cell_naive       True
# 28  CD8_T-cell_naive       True
# 29  CD8_T-cell_naive       True
# 30  CD8_T-cell_naive       True
# 31  CD8_T-cell_naive       True
# 32     NK-cell_naive       True
# 33     NK-cell_naive       True
# 34     NK-cell_naive       True
# 35     NK-cell_naive       True
# 36    monocyte_naive      False
# 37    monocyte_naive      False
# 38    monocyte_naive      False
# 39    monocyte_naive      False
# 40    monocyte_naive      False
# 41    monocyte_naive      False
# 42    monocyte_naive      False
# 43    monocyte_naive      False
# 44    monocyte_naive      False
# 45    monocyte_naive      False
# 46    monocyte_naive      False
# 47    monocyte_naive      False

# %% [markdown]
# ## Combining the other datasets

# %%
# loading and concat all the data
data = []
sgls_annos = [x for x in glob.glob('results/main/sgls/*/*/*/*/master.tsv') if 'sgls_20220222' in x]
sgls_annos = [x for x in glob.glob('results/main/sgls/*/*/*/*/master.tsv') if 'sgls_20220222' not in x]

# %%
sgls_annos
# Out:
# ['results/main/sgls/T1D_32005708/Schmiedel_2018/CD4_T-cell_anti-CD3-CD28/CD4_T-cell_naive/master.tsv',
#  'results/main/sgls/T1D_32005708/Schmiedel_2018/CD8_T-cell_naive/CD8_T-cell_naive/master.tsv',
#  'results/main/sgls/T1D_32005708/Schmiedel_2018/NK-cell_naive/NK-cell_naive/master.tsv',
#  'results/main/sgls/T1D_32005708/Schmiedel_2018/CD8_T-cell_anti-CD3-CD28/CD8_T-cell_naive/master.tsv',
#  'results/main/sgls/T1D_32005708/Schmiedel_2018/B-cell_naive/B-cell_naive/master.tsv',
#  'results/main/sgls/T1D_32005708/Schmiedel_2018/monocyte_CD16_naive/monocyte_naive/master.tsv',
#  'results/main/sgls/T1D_32005708/Schmiedel_2018/monocyte_naive/monocyte_naive/master.tsv',
#  'results/main/sgls/T1D_32005708/Quach_2016/monocyte_IAV/monocyte_naive/master.tsv',
#  'results/main/sgls/T1D_25751624/Schmiedel_2018/CD4_T-cell_naive/CD4_T-cell_naive/master.tsv',
#  'results/main/sgls/T1D_25751624/Schmiedel_2018/monocyte_naive/monocyte_naive/master.tsv',
#  'results/main/sgls/T1D_25751624/Schmiedel_2018/CD4_T-cell_anti-CD3-CD28/CD4_T-cell_naive/master.tsv',
#  'results/main/sgls/T1D_25751624/Schmiedel_2018/monocyte_CD16_naive/monocyte_naive/master.tsv',
#  'results/main/sgls/T1D_25751624/Schmiedel_2018/CD8_T-cell_anti-CD3-CD28/CD8_T-cell_naive/master.tsv',
#  'results/main/sgls/T1D_25751624/Schmiedel_2018/B-cell_naive/B-cell_naive/master.tsv',
#  'results/main/sgls/T1D_25751624/Schmiedel_2018/NK-cell_naive/NK-cell_naive/master.tsv',
#  'results/main/sgls/T1D_25751624/Quach_2016/monocyte_R848/monocyte_naive/master.tsv',
#  'results/main/sgls/T1D_25751624/Quach_2016/monocyte_IAV/monocyte_naive/master.tsv',
#  'results/main/sgls/T1D_25751624/Quach_2016/monocyte_LPS/monocyte_naive/master.tsv',
#  'results/main/sgls/T1D_25751624/Quach_2016/monocyte_Pam3CSK4/monocyte_naive/master.tsv',
#  'results/main/sgls/T1D_34012112_Gaulton/Schmiedel_2018/CD8_T-cell_naive/CD8_T-cell_naive/master.tsv',
#  'results/main/sgls/T1D_34012112_Gaulton/Schmiedel_2018/CD8_T-cell_anti-CD3-CD28/CD8_T-cell_naive/master.tsv',
#  'results/main/sgls/T1D_34012112_Gaulton/Schmiedel_2018/NK-cell_naive/NK-cell_naive/master.tsv',
#  'results/main/sgls/T1D_34012112_Gaulton/Schmiedel_2018/CD4_T-cell_anti-CD3-CD28/CD4_T-cell_naive/master.tsv',
#  'results/main/sgls/T1D_34012112_Gaulton/Schmiedel_2018/CD4_T-cell_naive/CD4_T-cell_naive/master.tsv',
#  'results/main/sgls/T1D_34012112_Gaulton/Schmiedel_2018/B-cell_naive/B-cell_naive/master.tsv',
#  'results/main/sgls/T1D_34012112_Gaulton/Quach_2016/monocyte_Pam3CSK4/monocyte_naive/master.tsv',
#  'results/main/sgls/T1D_34012112_Gaulton/Quach_2016/monocyte_R848/monocyte_naive/master.tsv',
#  'results/main/sgls/T1D_34012112_Gaulton/Quach_2016/monocyte_IAV/monocyte_naive/master.tsv']

# %%
for fn in sgls_annos:
        
    gwas_source = fn.split('/')[3]
    eqtl_source = fn.split('/')[4]
    ge_source = fn.split('/')[5]
    loop_source = fn.split('/')[6]    
    
    df = pd.read_table(fn, header=0)
    df['gwas_source'] = gwas_source
    df['eqtl_source'] = eqtl_source
    df['ge_source'] = ge_source
    df['loop_source'] = loop_source
    
    # combine the columns gene_id and geneid
    #df.loc[~df['gene_id'].isna(), 'geneid'] = df.loc[~df['gene_id'].isna(), 'gene_id']
    #df.loc[:, 'gene_name'] = df.loc[:, 'geneid'].apply(lambda x: gene_dict[x])
    df = df.loc[(df.is_coloc_pair == 1) & (df.has_fithichip_loop == 1)]
    
    if df.shape[0] > 0: 
        data.append(df)
        
data = pd.concat(data)

# %%
data
# Out:
#             sid       rsid           geneid   gene_name  chrom    snp_pos  \
# 42   10:6068912  rs7090530  ENSG00000213994  AL157395.1  chr10    6068912
# 27  21:42405613  rs9981624  ENSG00000160183     TMPRSS3  chr21   42405613
# 22  2:203875100   rs231724  ENSG00000163599       CTLA4   chr2  203875100
#
#     tss_start    tss_end  is_eqtl_pair  is_coloc_pair  is_closest_gene  \
# 42    6202692    6202693             0              1                0
# 27   42396845   42396846             1              1                0
# 22  203867770  203867771             0              1                1
#
#     has_fithichip_loop  has_colocSNP_anchor     eqtl_pval  eqtl_beta  \
# 42                   1                    0  2.746830e-02   0.338513
# 27                   1                    0  6.365800e-11   0.870668
# 22                   1                    0  1.846690e-02  -0.482733
#
#         dist  ppH0  ppH1          ppH2      ppH3      ppH4  gene_start  \
# 42  133781.0   0.0   0.0  4.833528e-03  0.070616  0.924551     6197612
# 27    8767.0   0.0   0.0  6.053392e-02  0.120225  0.819241    42371837
# 22    7329.0   0.0   0.0  3.471615e-09  0.103521  0.896479   203867771
#
#      gene_end ref alt      AC        AF      AN  gwas_slope  gwas_slope_se  \
# 42    6202693   C   A  3112.0  0.621406  5008.0    0.185500       0.024500
# 27   42396846   G   C  1175.0  0.234625  5008.0    0.152034       0.019004
# 22  203873965   A   G  2094.0  0.418131  5008.0    0.174961       0.018996
#
#        gwas_pval  gene_start.1  gene_end.1 gene_strand   gwas_source  \
# 42  4.026000e-14       6197612     6202693           -  T1D_32005708
# 27  1.244192e-15      42371837    42396846           -  T1D_25751624
# 22  3.245297e-20     203867771   203873965           +  T1D_25751624
#
#        eqtl_source            ge_source       loop_source
# 42  Schmiedel_2018     CD8_T-cell_naive  CD8_T-cell_naive
# 27  Schmiedel_2018     CD4_T-cell_naive  CD4_T-cell_naive
# 22  Schmiedel_2018  monocyte_CD16_naive    monocyte_naive

# %% [markdown]
# ### Checking the uniq set of genes

# %%
unique_genes = data.geneid.unique()
unique_genes = [x for x in unique_genes if type(x) == str]
unique_gnames = [gene_dict[x] if x in gene_dict else x for x in unique_genes]
unique_genes_df = pd.DataFrame([unique_genes, unique_gnames]).T
unique_genes_df.columns = ['geneid', 'genename']
unique_genes_df
# Out:
#             geneid    genename
# 0  ENSG00000213994  AL157395.1
# 1  ENSG00000160183     TMPRSS3
# 2  ENSG00000163599       CTLA4

# %%
# find the unique SNPs
uniq_snps_by_cells = data.groupby('ge_source').sid.nunique()
uniq_snps_by_cells = uniq_snps_by_cells.to_frame()

# find the unique genes 
uniq_genes_by_cells = data.groupby('ge_source').geneid.nunique()
uniq_genes_by_cells = uniq_genes_by_cells.to_frame()

# merge snps and genes
uniq_counts_by_cells = pd.merge(uniq_snps_by_cells, uniq_genes_by_cells, left_index=True, right_index=True)
uniq_counts_by_cells.columns = ['Number of Unique SNPs', 'Number of Unique Genes']
uniq_counts_by_cells.index.name = 'Cell Line'

# %%
# save the file
excel_analysis = os.path.join(outdir, 'Unique_Counts_By_Cell_Line.xlsx')
uniq_counts_by_cells.to_excel(excel_analysis, sheet_name='pieqtls')

# %%
uniq_genes_by_cells
# Out:
#                      geneid
# ge_source
# CD4_T-cell_naive          1
# CD8_T-cell_naive          1
# monocyte_CD16_naive       1

# %%
excel_analysis
# Out:
# 'results/main/sgls/combined/Unique_Counts_By_Cell_Line.xlsx'

# %% [markdown]
# #### Write the gene list as well

# %%
gh_list = sorted(unique_genes_df.geneid.unique().tolist())
gh_fn = os.path.join(outdir, 'gene_list.txt')
with open(gh_fn, 'w') as fw:
    for x in gh_list:
        fw.write('{}\n'.format(x))

# %%
gh_fn
# Out:
# 'results/main/sgls/combined/gene_list.txt'

# %% [markdown]
# ### Analyzing the Number of eQTLs, loops, colocaled SNP-Gene (per DataSet)

# %%
cells_with_loops = data[data.has_fithichip_loop == 1]
uniq_cells = cells_with_loops[['eqtl_source', 'ge_source', 'loop_source']].values.tolist()
uniq_cells = set([tuple(x) for x in uniq_cells])
uniq_cells = list(uniq_cells)
uniq_cells = pd.DataFrame(uniq_cells)
uniq_cells.columns = ['eqtl_source', 'ge_source', 'loop_source']
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [14], in <module>
# ----> 1 cells_with_loops = data[data.has_fithichip_loop == 1]
#       2 uniq_cells = cells_with_loops[['eqtl_source', 'ge_source', 'loop_source']].values.tolist()
#       3 uniq_cells = set([tuple(x) for x in uniq_cells])
#
# File ~/software/anaconda3/hichip-db/lib/python3.10/site-packages/pandas/core/frame.py:3497, in DataFrame.__getitem__(self, key)
#    3495 # Do we have a (boolean) 1d indexer?
#    3496 if com.is_bool_indexer(key):
# -> 3497     return self._getitem_bool_array(key)
#    3499 # We are left with two options: a single key, and a collection of keys,
#    3500 # We interpret tuples as collections only for non-MultiIndex
#    3501 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File ~/software/anaconda3/hichip-db/lib/python3.10/site-packages/pandas/core/frame.py:3552, in DataFrame._getitem_bool_array(self, key)
#    3550 key = check_bool_indexer(self.index, key)
#    3551 indexer = key.nonzero()[0]
# -> 3552 return self._take_with_is_copy(indexer, axis=0)
#
# File ~/software/anaconda3/hichip-db/lib/python3.10/site-packages/pandas/core/generic.py:3728, in NDFrame._take_with_is_copy(self, indices, axis)
#    3720 def _take_with_is_copy(self: NDFrameT, indices, axis=0) -> NDFrameT:
#    3721     """
#    3722     Internal version of the `take` method that sets the `_is_copy`
#    3723     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    3726     See the docstring of `take` for full explanation of the parameters.
#    3727     """
# -> 3728     result = self.take(indices=indices, axis=axis)
#    3729     # Maybe set copy if we didn't actually change the index.
#    3730     if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File ~/software/anaconda3/hichip-db/lib/python3.10/site-packages/pandas/core/generic.py:3713, in NDFrame.take(self, indices, axis, is_copy, **kwargs)
#    3704     warnings.warn(
#    3705         "is_copy is deprecated and will be removed in a future version. "
#    3706         "'take' always returns a copy, so there is no need to specify this.",
#    3707         FutureWarning,
#    3708         stacklevel=find_stack_level(),
#    3709     )
#    3711 nv.validate_take((), kwargs)
# -> 3713 self._consolidate_inplace()
#    3715 new_data = self._mgr.take(
#    3716     indices, axis=self._get_block_manager_axis(axis), verify=True
#    3717 )
#    3718 return self._constructor(new_data).__finalize__(self, method="take")
#
# File ~/software/anaconda3/hichip-db/lib/python3.10/site-packages/pandas/core/generic.py:5661, in NDFrame._consolidate_inplace(self)
#    5658 def f():
#    5659     self._mgr = self._mgr.consolidate()
# -> 5661 self._protect_consolidate(f)
#
# File ~/software/anaconda3/hichip-db/lib/python3.10/site-packages/pandas/core/generic.py:5649, in NDFrame._protect_consolidate(self, f)
#    5647     return f()
#    5648 blocks_before = len(self._mgr.blocks)
# -> 5649 result = f()
#    5650 if len(self._mgr.blocks) != blocks_before:
#    5651     self._clear_item_cache()
#
# File ~/software/anaconda3/hichip-db/lib/python3.10/site-packages/pandas/core/generic.py:5659, in NDFrame._consolidate_inplace.<locals>.f()
#    5658 def f():
# -> 5659     self._mgr = self._mgr.consolidate()
#
# File ~/software/anaconda3/hichip-db/lib/python3.10/site-packages/pandas/core/internals/managers.py:631, in BaseBlockManager.consolidate(self)
#     629 bm = type(self)(self.blocks, self.axes, verify_integrity=False)
#     630 bm._is_consolidated = False
# --> 631 bm._consolidate_inplace()
#     632 return bm
#
# File ~/software/anaconda3/hichip-db/lib/python3.10/site-packages/pandas/core/internals/managers.py:1685, in BlockManager._consolidate_inplace(self)
#    1683 def _consolidate_inplace(self) -> None:
#    1684     if not self.is_consolidated():
# -> 1685         self.blocks = tuple(_consolidate(self.blocks))
#    1686         self._is_consolidated = True
#    1687         self._known_consolidated = True
#
# File ~/software/anaconda3/hichip-db/lib/python3.10/site-packages/pandas/core/internals/managers.py:2084, in _consolidate(blocks)
#    2082 new_blocks: list[Block] = []
#    2083 for (_can_consolidate, dtype), group_blocks in grouper:
# -> 2084     merged_blocks = _merge_blocks(
#    2085         list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    2086     )
#    2087     new_blocks = extend_blocks(merged_blocks, new_blocks)
#    2088 return new_blocks
#
# File ~/software/anaconda3/hichip-db/lib/python3.10/site-packages/pandas/core/internals/managers.py:2118, in _merge_blocks(blocks, dtype, can_consolidate)
#    2115     new_values = bvals2[0]._concat_same_type(bvals2, axis=0)
#    2117 argsort = np.argsort(new_mgr_locs)
# -> 2118 new_values = new_values[argsort]
#    2119 new_mgr_locs = new_mgr_locs[argsort]
#    2121 bp = BlockPlacement(new_mgr_locs)
#
# MemoryError: Unable to allocate 1.42 GiB for an array with shape (28, 6788669) and data type float64

# %%
uniq_cells.sort_values('ge_source')

# %%
# group by the dataset combos
eqtl_ge_grps = data.groupby(['eqtl_source', 'ge_source', 'loop_source'])

# calculate the number of sg pairs 
def count_uniq(x):
    v = x[['sid', 'geneid']].values.tolist()
    v = [tuple(x) for x in v]
    v = set(v)
    return(len(v))
eqtl_ge_sg_pairs = eqtl_ge_grps.apply(count_uniq).to_frame()
eqtl_ge_sg_pairs.columns = ['num_sg_pairs']

# calculate the number of sg pairs with loops
eqtl_ge_loops = eqtl_ge_grps.has_fithichip_loop.sum().to_frame()

# calculate the number of sg pairs with significant eQTL signal
eqtl_ge_eqtl = eqtl_ge_grps.is_eqtl_pair.sum().to_frame()

# calculate the number of sg pairs with significant coloc 
eqtl_ge_coloc = eqtl_ge_grps.is_coloc_pair.sum().to_frame()

# %%
eqtl_ge_master = eqtl_ge_sg_pairs.merge(eqtl_ge_coloc, left_index=True, right_index=True)
eqtl_ge_master = eqtl_ge_master.merge(eqtl_ge_eqtl, left_index=True, right_index=True)
eqtl_ge_master = eqtl_ge_master.merge(eqtl_ge_loops, left_index=True, right_index=True)

eqtl_ge_master.columns = ['Number of\\nSNP-Gene Pairs',
                          'Number of\\nColoc Pairs',
                          'Number of\\neQTL Pairs',
                          'Number of\\nPairs with a Loop']
eqtl_ge_master.index.names = ['eQTL Source', 'GE Source', 'Loop Source']

# %%
HTML(eqtl_ge_master.to_html().replace('\\n', '<br>'))

# %% [markdown]
# #### Extract all pairs with a significant eQTL

# %%
sg_with_eqtl = data.loc[(data.is_eqtl_pair == 1), major_cols]

# %%
print('There are {} SNP-Gene pairs with an eQTL.'.format(len(sg_with_eqtl)))

# %%
sg_with_eqtl

# %% [markdown]
# #### Extract all pairs with a colocalization

# %%
sg_with_coloc = data.loc[(data.is_coloc_pair == 1), major_cols]

# %%
print('There are {} SNP-Gene pairs with a coloc.'.format(len(sg_with_coloc)))

# %%
sg_with_coloc

# %% [markdown]
# #### Extract all pairs with a FitHiChIP Loop

# %%
sg_with_loops = data.loc[(data.has_fithichip_loop == 1), major_cols]

# %%
print('There are {} SNP-Gene pairs with a loop.'.format(len(sg_with_loops)))

# %%
sg_with_loops

# %% [markdown]
# ## Finalizing the super master table

# %%
#data = data.loc[:, new_order]
data.drop_duplicates(subset=['sid', 'geneid', 'eqtl_source', 'ge_source', 'loop_source'], inplace=True)
master_fn = os.path.join(outdir, 'super_master.snp_gene_loop.analysis.tsv')
data[major_cols].to_csv(master_fn, sep='\t', index=False, na_rep='nan')

# %%
master_fn = os.path.join(outdir, 'super_master.snp_gene_loop.analysis.xlsx')
xdata = data.sort_values(['rsid', 'gwas_source','eqtl_source', 'ge_source', 'loop_source', 'geneid'])
xdata = xdata[major_cols].set_index(['rsid', 'gwas_source','eqtl_source', 'ge_source', 'loop_source', 'geneid'])
xdata.to_excel(master_fn, na_rep='nan')
