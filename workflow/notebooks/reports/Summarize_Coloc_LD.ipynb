# %%
import os 
import glob
import pandas as pd 
os.chdir('/mnt/BioHome/jreyna/jreyna/projects/dchallenge/')

# %% [markdown]
# ## Load Coloc SNP data

# %%
globs = 'results/main/GRCh37/coloc/Results/eQTL_Catalogue/*/*/*/FINAL_Summary_Coloc_Gene_SNP_Pairs.bed'
globs = glob.glob(globs)

coloc_data = []
for fn in globs:
    
    file_info = fn.split('/')    
    gwas_source = file_info[6]
    eqtl_source = file_info[7]
    ge_source = file_info[8]
    
    num_lines = len(open(fn).readlines())
    if num_lines > 0: 
        
        #print(fn)
        
        tdf = pd.read_table(fn)
        tdf.loc[:, 'gwas_source'] = gwas_source
        tdf.loc[:, 'eqtl_source'] = eqtl_source
        tdf.loc[:, 'ge_source'] = ge_source
    
        coloc_data.append(tdf)

coloc_data = pd.concat(coloc_data)

# %%
coloc_summary = coloc_data.groupby(['gwas_source', 'eqtl_source', 'ge_source'])#.pos.count()
coloc_summary = coloc_summary.pos.count().to_frame()
coloc_summary.columns = ['Number of SNPs in Coloc']
coloc_summary
# Out:
#                                                               Number of SNPs in Coloc
# gwas_source               eqtl_source    ge_source
# T1D_25751624              BLUEPRINT      T-cell                                     1
#                                          monocyte                                   1
#                                          neutrophil                                 1
#                           GENCORD        LCL                                        2
#                                          T-cell                                     2
# ...                                                                               ...
# T1D_34594039_GCST90018925 Schmiedel_2018 Tfh_memory                                 2
#                                          Th17_memory                                1
#                                          Th1_memory                                 1
#                                          Th2_memory                                 1
#                                          monocyte_CD16_naive                        1
#
# [83 rows x 1 columns]

# %% [markdown]
# ## Load LD data

# %%
globs = glob.glob('results/main/GRCh37/coloc/eQTL_Catalogue/*/*/*/ldpairs/coloc_ld_snps.txt')

# %%
ld_data = []
ld_summary_zeros = []
for fn in globs:
    
    file_info = fn.split('/')
    gwas_source = file_info[5]
    genome_ref = 'GRCh37'
    eqtl_source = file_info[6]
    ge_source = file_info[7]
    
    num_lines = len(open(fn).readlines())
    if num_lines > 0: 
        
        tdf = pd.read_table(fn)
        tdf.loc[:, 'gwas_source'] = gwas_source
        tdf.loc[:, 'genome_ref'] = genome_ref
        tdf.loc[:, 'eqtl_source'] = eqtl_source
        tdf.loc[:, 'ge_source'] = ge_source
        tdf.drop_duplicates(subset=['rsID', 'ld_rsID'], inplace=True)
        ld_data.append(tdf)
        
    else:
        ld_summary_zeros.append([gwas_source, eqtl_source, ge_source, 0])

# %%
ld_df = pd.concat(ld_data)

# %%
ld_summary = ld_df.groupby(['gwas_source', 'eqtl_source', 'ge_source'])#.pos.count()
ld_summary = ld_summary.pos.count().to_frame()
ld_summary.columns = ['Number of SNPs in LD']

# %%
# add entries which have zero SNPs in LD
if len(ld_summary_zeros) > 0:
    ld_summary_zeros = pd.DataFrame(ld_summary_zeros)
    ld_summary_zeros.set_index([0,1,2], inplace=True)
    ld_summary_zeros.columns = ['Number of SNPs in LD']
    ld_summary = pd.concat([ld_summary, ld_summary_zeros])

# %% [markdown]
# ## Merge

# %%
pd.options.display.min_rows = 100

# %%
summary = pd.merge(coloc_summary, ld_summary, left_index=True, right_index=True, how='outer')
summary.sort_values('Number of SNPs in LD', ascending=False)
# Out:
#                                                                      Number of SNPs in Coloc  \
# gwas_source               eqtl_source      ge_source
# T1D_25751624              Schmiedel_2018   Tfh_memory                                      4
#                           Quach_2016       monocyte_R848                                   2
#                                            monocyte_LPS                                    1
# T1D_34012112_Gaulton      Schmiedel_2018   Treg_naive                                      5
#                           BLUEPRINT        T-cell                                          2
# T1D_25751624              Schmiedel_2018   NK-cell_naive                                   3
# T1D_34012112_Gaulton      Schmiedel_2018   CD4_T-cell_anti-CD3-CD28                        3
# T1D_25751624              Schmiedel_2018   Th1-17_memory                                   2
#                                            CD8_T-cell_anti-CD3-CD28                        4
# T1D_34012112_Gaulton      Schmiedel_2018   Th2_memory                                      4
#                           Quach_2016       monocyte_R848                                   3
# T1D_25751624              Schmiedel_2018   B-cell_naive                                    2
# T1D_34012112_Gaulton      Schmiedel_2018   Th1-17_memory                                   2
#                                            Th1_memory                                      4
# T1D_25751624              GENCORD          T-cell                                          2
#                           Schmiedel_2018   Th17_memory                                     2
#                           GTEx             LCL                                             3
#                           GENCORD          LCL                                             2
# T1D_34012112_Gaulton      Schmiedel_2018   CD8_T-cell_naive                                1
#                           BLUEPRINT        neutrophil                                      2
#                           Schmiedel_2018   Tfh_memory                                      2
#                                            Treg_memory                                     2
# T1D_25751624              Quach_2016       monocyte_naive                                  2
#                                            monocyte_IAV                                    2
#                           Schmiedel_2018   CD4_T-cell_anti-CD3-CD28                        2
#                                            Treg_memory                                     1
#                                            Treg_naive                                      1
#                           BLUEPRINT        neutrophil                                      1
#                           Schmiedel_2018   Th1_memory                                      1
# T1D_34594039_GCST90018925 Schmiedel_2018   CD8_T-cell_anti-CD3-CD28                        1
# ...                                                                                      ...
# T1D_32005708              BLUEPRINT        neutrophil                                      1
# T1D_34012112_Gaulton      Schmiedel_2018   B-cell_naive                                    1
# T1D_25751624              Lepik_2017       blood                                           1
#                           GTEx             blood                                           1
# T1D_34594039_GCST90018925 Schmiedel_2018   Th17_memory                                     1
#                           GTEx             LCL                                             1
# T1D_25751624              BLUEPRINT        monocyte                                        1
# T1D_34012112_Gaulton      Schmiedel_2018   NK-cell_naive                                   1
# T1D_32005708              Schmiedel_2018   Tfh_memory                                      2
# T1D_34012112_Gaulton      van_de_Bunt_2015 pancreatic_islet                                1
# T1D_25751624              van_de_Bunt_2015 pancreatic_islet                                1
# T1D_34012112_Gaulton      Quach_2016       monocyte_Pam3CSK4                               1
# T1D_25751624              Schmiedel_2018   Th2_memory                                      2
# T1D_34594039_GCST90018925 Schmiedel_2018   Th2_memory                                      1
#                                            monocyte_CD16_naive                             1
# T1D_32005708              Schmiedel_2018   Th2_memory                                      1
# T1D_34012112_Gaulton      Schmiedel_2018   Th17_memory                                     3
# T1D_25751624              BLUEPRINT        T-cell                                          1
# T1D_34594039_GCST90018925 GTEx             pancreas                                        1
# T1D_32005708              Quach_2016       monocyte_IAV                                    1
# T1D_34012112_Gaulton      Schmiedel_2018   CD4_T-cell_naive                                1
# T1D_32005708              Schmiedel_2018   Treg_naive                                      1
#                                            Th17_memory                                     1
#                           Lepik_2017       blood                                           1
#                           GTEx             LCL                                             1
#                           Schmiedel_2018   Treg_memory                                     1
#                                            Th1_memory                                      1
#                                            CD8_T-cell_naive                                1
# T1D_25751624              Schmiedel_2018   monocyte_naive                                  1
# T1D_34012112_Gaulton      Schmiedel_2018   test                                            1
#
#                                                                      Number of SNPs in LD
# gwas_source               eqtl_source      ge_source
# T1D_25751624              Schmiedel_2018   Tfh_memory                               335.0
#                           Quach_2016       monocyte_R848                            289.0
#                                            monocyte_LPS                             252.0
# T1D_34012112_Gaulton      Schmiedel_2018   Treg_naive                               216.0
#                           BLUEPRINT        T-cell                                   133.0
# T1D_25751624              Schmiedel_2018   NK-cell_naive                            129.0
# T1D_34012112_Gaulton      Schmiedel_2018   CD4_T-cell_anti-CD3-CD28                 120.0
# T1D_25751624              Schmiedel_2018   Th1-17_memory                            104.0
#                                            CD8_T-cell_anti-CD3-CD28                 102.0
# T1D_34012112_Gaulton      Schmiedel_2018   Th2_memory                                96.0
#                           Quach_2016       monocyte_R848                             90.0
# T1D_25751624              Schmiedel_2018   B-cell_naive                              89.0
# T1D_34012112_Gaulton      Schmiedel_2018   Th1-17_memory                             82.0
#                                            Th1_memory                                74.0
# T1D_25751624              GENCORD          T-cell                                    70.0
#                           Schmiedel_2018   Th17_memory                               70.0
#                           GTEx             LCL                                       67.0
#                           GENCORD          LCL                                       64.0
# T1D_34012112_Gaulton      Schmiedel_2018   CD8_T-cell_naive                          63.0
#                           BLUEPRINT        neutrophil                                59.0
#                           Schmiedel_2018   Tfh_memory                                57.0
#                                            Treg_memory                               54.0
# T1D_25751624              Quach_2016       monocyte_naive                            53.0
#                                            monocyte_IAV                              52.0
#                           Schmiedel_2018   CD4_T-cell_anti-CD3-CD28                  51.0
#                                            Treg_memory                               50.0
#                                            Treg_naive                                50.0
#                           BLUEPRINT        neutrophil                                46.0
#                           Schmiedel_2018   Th1_memory                                46.0
# T1D_34594039_GCST90018925 Schmiedel_2018   CD8_T-cell_anti-CD3-CD28                  44.0
# ...                                                                                   ...
# T1D_32005708              BLUEPRINT        neutrophil                                37.0
# T1D_34012112_Gaulton      Schmiedel_2018   B-cell_naive                              31.0
# T1D_25751624              Lepik_2017       blood                                     24.0
#                           GTEx             blood                                     24.0
# T1D_34594039_GCST90018925 Schmiedel_2018   Th17_memory                               22.0
#                           GTEx             LCL                                       22.0
# T1D_25751624              BLUEPRINT        monocyte                                  21.0
# T1D_34012112_Gaulton      Schmiedel_2018   NK-cell_naive                             21.0
# T1D_32005708              Schmiedel_2018   Tfh_memory                                20.0
# T1D_34012112_Gaulton      van_de_Bunt_2015 pancreatic_islet                          19.0
# T1D_25751624              van_de_Bunt_2015 pancreatic_islet                          18.0
# T1D_34012112_Gaulton      Quach_2016       monocyte_Pam3CSK4                         17.0
# T1D_25751624              Schmiedel_2018   Th2_memory                                17.0
# T1D_34594039_GCST90018925 Schmiedel_2018   Th2_memory                                15.0
#                                            monocyte_CD16_naive                       15.0
# T1D_32005708              Schmiedel_2018   Th2_memory                                15.0
# T1D_34012112_Gaulton      Schmiedel_2018   Th17_memory                               14.0
# T1D_25751624              BLUEPRINT        T-cell                                    14.0
# T1D_34594039_GCST90018925 GTEx             pancreas                                   8.0
# T1D_32005708              Quach_2016       monocyte_IAV                               6.0
# T1D_34012112_Gaulton      Schmiedel_2018   CD4_T-cell_naive                           5.0
# T1D_32005708              Schmiedel_2018   Treg_naive                                 5.0
#                                            Th17_memory                                5.0
#                           Lepik_2017       blood                                      5.0
#                           GTEx             LCL                                        5.0
#                           Schmiedel_2018   Treg_memory                                4.0
#                                            Th1_memory                                 4.0
#                                            CD8_T-cell_naive                           4.0
# T1D_25751624              Schmiedel_2018   monocyte_naive                             2.0
# T1D_34012112_Gaulton      Schmiedel_2018   test                                       NaN
#
# [83 rows x 2 columns]
