# %%
import os 
import pandas as pd
import subprocess
import glob
import pybedtools as pbt 
pd.set_option('display.max_columns', None)

pbt.set_bedtools_path('/mnt/BioApps/bedtools/bin/')

os.chdir('/mnt/BioHome/jreyna/jreyna/projects/dchallenge/')

genome_sizes = 'results/refs/hg19/hg19.chrom.sizes'

# make the directory to save our data
outdir = 'results/main/gwas_pieqtls/2021_chiou_et_al/2021_chandra_et_al/'
os.makedirs(outdir, exist_ok=True)

# %%
gs_fn = 'results/refs/hg19/hg19.chrom.nochr.sizes'
gencode_fn = 'results/refs/gencode/v30/gencode.v30.annotation.bed'
gencode = pd.read_table(gencode_fn, header=None)
gencode = gencode.drop_duplicates(5)
gencode_dict = {k:v for k,v in gencode[[5,6]].values.tolist()} 
gencode_dict.update({v:k for k,v in gencode[[5,6]].values.tolist()})

# %% [markdown]
# ## Load Fine Mapped GWAS

# %%
data = []
gwas = 'results/main/finemapping/*/GRCh37/offset_1000000/Summary/sss/FINAL_top_snp_credible_set.txt'
for fn in glob.glob(gwas):
    path_info = fn.split('/')
    df = pd.read_table(fn)
    df['gwas_source'] = path_info[3]
    data.append(df)
gwas_df = pd.concat(data)
gwas_df.loc[:, 'chromosome'] = 'chr' + gwas_df.loc[:, 'chromosome'].astype(str)

# loading finemap data into bedtools
gwas_bed = gwas_df.iloc[:, [4,5,5]]
gwas_bed.columns = ['chrom', 'start', 'end']
gwas_bed['start'] = gwas_bed['start'] - 1
gwas_pbt = pbt.BedTool.from_dataframe(gwas_bed)
# Out:
# /tmp/ipykernel_16022/1426260480.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwas_bed['start'] = gwas_bed['start'] - 1

# %%
gwas_df.head()
# Out:
#    regionID                  GWASLoci  index         rsid chromosome  \
# 0         1  chr1:113310083-115099755   2336  1:114089649       chr1
# 1         1  chr1:113310083-115099755   2829  1:114270326       chr1
# 2         1  chr1:113310083-115099755   5046  1:114909703       chr1
# 3         1  chr1:113310083-115099755   3035  1:114377568       chr1
# 4         1  chr1:113310083-115099755   3131  1:114420328       chr1
#
#     position allele1 allele2       maf    beta      se          z  prob  \
# 0  114089649       A       G  0.016251 -0.1324  0.0749  -1.767690   1.0
# 1  114270326       A       C  0.260388 -0.1634  0.0209  -7.818180   1.0
# 2  114909703       T       C  0.131631 -0.0046  0.0261  -0.176245   1.0
# 3  114377568       G       A  0.114168 -0.4287  0.0286 -14.989500   1.0
# 4  114420328       T       C  0.325922  0.1320  0.0189   6.984130   1.0
#
#    log10bf      mean        sd  mean_incl   sd_incl          pval  \
# 0  13.5586  0.001264  0.000008   0.001264  0.000008  9.614436e-01
# 1  13.5586  0.001264  0.000008   0.001264  0.000008  1.000000e+00
# 2  13.5586  0.001264  0.000008   0.001264  0.000008  5.699493e-01
# 3  13.5586  0.001264  0.000008   0.001264  0.000008  1.000000e+00
# 4  13.5586  0.001264  0.000008   0.001264  0.000008  1.433164e-12
#
#                  gwas_source
# 0  T1D_34594039_GCST90018925
# 1  T1D_34594039_GCST90018925
# 2  T1D_34594039_GCST90018925
# 3  T1D_34594039_GCST90018925
# 4  T1D_34594039_GCST90018925

# %%
gwas_pbt = pbt.BedTool.from_dataframe(gwas_bed)

# %% [markdown]
# ## Load pieQTLs

# %%
pieqtls = glob.glob('results/main/pieqtls/2021_chandra_et_al/*/proximal.pieqtls.tsv')

pieqtl_data = []
for pieqtl in pieqtls:
    print(pieqtl)
    
    cline = pieqtl.split('/')[-2]
    df = pd.read_table(pieqtl)    
    df['cline'] = cline
    pieqtl_data.append(df) 

pieqtl_df = pd.concat(pieqtl_data)
pieqtl_df['Chromosome'] = pieqtl_df['Chromosome']
# Out:
# results/main/pieqtls/2021_chandra_et_al/B-cell_naive/proximal.pieqtls.tsv
# results/main/pieqtls/2021_chandra_et_al/NK-cell_naive/proximal.pieqtls.tsv
# results/main/pieqtls/2021_chandra_et_al/monocyte_naive/proximal.pieqtls.tsv
# results/main/pieqtls/2021_chandra_et_al/CD4_T-cell_naive/proximal.pieqtls.tsv
# results/main/pieqtls/2021_chandra_et_al/CD8_T-cell_naive/proximal.pieqtls.tsv

# %%
pieqtl_df
# Out:
#       pieQTL.ID Chromosome  pieQTL.Position       Target_geneID  \
# 0     rs9488914       chr6        116690849  ENSG00000111817.12
# 1     rs2304748       chr8         33369944  ENSG00000172728.11
# 2     rs2581897       chr8         33371146  ENSG00000172728.11
# 3     rs2581899       chr8         33371199  ENSG00000172728.11
# 4     rs2732288       chr8         33370757  ENSG00000172728.11
# ...         ...        ...              ...                 ...
# 6304  rs8100318      chr19         21690009   ENSG00000172687.9
# 6305  rs6708331       chr2         70368923   ENSG00000116005.7
# 6306   rs402034       chr8         17554157   ENSG00000129422.9
# 6307   rs551244      chr19          5961883   ENSG00000187650.3
# 6308   rs639251      chr19          5962530   ENSG00000187650.3
#
#      Target_geneName        TSS        pvalue    FDR (DICE)  beta ref alt  \
# 0                DSE  116575336  1.340000e-29  5.210000e-24 -1.22   C   T
# 1              FUT10   33330940  1.080000e-27  2.200000e-22 -1.26   T   C
# 2              FUT10   33330940  1.080000e-27  2.200000e-22 -1.26   T   G
# 3              FUT10   33330940  1.080000e-27  2.200000e-22 -1.26   T   C
# 4              FUT10   33330940  1.080000e-27  2.200000e-22 -1.26   G   A
# ...              ...        ...           ...           ...   ...  ..  ..
# 6304          ZNF738   21541732  6.060000e-05  4.953556e-02 -0.70   A   G
# 6305          PCYOX1   70484518  7.520000e-05  4.969759e-02 -0.77   G   A
# 6306           MTUS1   17658426  5.300000e-05  4.976122e-02  0.69   C   A
# 6307            VMAC    5904869  6.090000e-05  4.976689e-02  0.62   G   C
# 6308            VMAC    5904869  6.090000e-05  4.976689e-02  0.62   C   T
#
#       Mean.TPM.Homozygous.Reference  Mean.TPM.Heterozygous  \
# 0                             21.77                  12.57
# 1                              5.24                   3.01
# 2                              5.24                   3.01
# 3                              5.24                   3.01
# 4                              5.24                   3.01
# ...                             ...                    ...
# 6304                          32.95                  24.97
# 6305                          45.91                  40.04
# 6306                           7.23                   8.91
# 6307                         130.13                 147.45
# 6308                         130.13                 147.45
#
#       Mean.TPM.Homozygous.Alternative Interaction_type GWAS.Trait  \
# 0                                4.70    Direct_pieQTL
# 1                                1.16    Direct_pieQTL
# 2                                1.16    Direct_pieQTL
# 3                                1.16    Direct_pieQTL
# 4                                1.16    Direct_pieQTL
# ...                               ...              ...        ...
# 6304                            21.60  Indirect_pieQTL
# 6305                            33.12  Indirect_pieQTL
# 6306                            10.10  Indirect_pieQTL
# 6307                           160.35  Indirect_pieQTL
# 6308                           160.35  Indirect_pieQTL
#
#                  cline
# 0         B-cell_naive
# 1         B-cell_naive
# 2         B-cell_naive
# 3         B-cell_naive
# 4         B-cell_naive
# ...                ...
# 6304  CD8_T-cell_naive
# 6305  CD8_T-cell_naive
# 6306  CD8_T-cell_naive
# 6307  CD8_T-cell_naive
# 6308  CD8_T-cell_naive
#
# [35898 rows x 17 columns]

# %%
pieqtl_bed = pieqtl_df.iloc[:, [1,2,2,-1]]
pieqtl_bed.columns = ['chrom', 'start', 'end', 'cline']
#pieqtl_bed.loc[:, 'chrom'] = 'chr' + pieqtl_bed.loc[:, 'chrom'].astype(str)
pieqtl_bed.loc[:, 'start'] = pieqtl_bed['start'] - 1
pieqtl_pbt = pbt.BedTool.from_dataframe(pieqtl_bed)
# Out:
# /tmp/ipykernel_16022/4048913792.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pieqtl_bed.loc[:, 'start'] = pieqtl_bed['start'] - 1

# %%
pieqtl_bed.shape
# Out:
# (35898, 4)

# %% [markdown]
# ## Intersect Fine Mapped GWAS and pieQTLs

# %%
major_cols = ['ge_source',
              'rsid',
             'chrom',
             'pos',
             'geneid',
             'genename',
             'allele1',
             'allele2',
             'maf',
             'beta_x',
             'se',
             'z',
             'prob',
             'log10bf',
             'mean',
             'sd',
             'mean_incl',
             'sd_incl',
             'pval',
             'gwas_source',
             'pieQTL.ID',
             'Chromosome',
             'pieQTL.Position',
             'Target_geneName',
             'TSS',
             'pvalue',
             'FDR (DICE)',
             'beta_y',
             'ref',
             'alt',
             'Mean.TPM.Homozygous.Reference',
             'Mean.TPM.Heterozygous',
             'Mean.TPM.Homozygous.Alternative',
             'Interaction_type',
             'GWAS.Trait',
             'cline',
             'regionID',
             'GWASLoci',
             'index']

# %% [markdown]
# ### No Slop Version

# %%
intersect_pbt = gwas_pbt.intersect(pieqtl_pbt, wa=True, wb=True)
intersect_df = intersect_pbt.to_dataframe()
intersect_df.columns = ['gwas_chr', 'gwas_start', 'gwas_end',
                       'pie_chr', 'pie_start', 'pie_end', 'ge_source']
intersect_df = intersect_df.merge(gwas_df, left_on=['gwas_chr', 'gwas_end'],
                                  right_on=['chromosome', 'position'],
                                  how='left')

intersect_df = intersect_df.merge(pieqtl_df, left_on=['pie_chr', 'pie_end', 'ge_source'],
                                  right_on=['Chromosome', 'pieQTL.Position', 'cline'],
                                  how='left')

# %%
intersect_df.loc[:, 'geneid'] = intersect_df['Target_geneID'].str.replace('\.[0-9]*', '', regex=True)
intersect_df.loc[:, 'genename'] = [gencode_dict[x] for x in intersect_df.loc[:, 'geneid'].values.tolist()]

# %%
intersect_df
# Out:
#   gwas_chr  gwas_start   gwas_end pie_chr  pie_start    pie_end  \
# 0     chr2   242294912  242294913    chr2  242294912  242294913
# 1     chr2   242294912  242294913    chr2  242294912  242294913
# 2     chr2   242294912  242294913    chr2  242294912  242294913
# 3     chr2   242294912  242294913    chr2  242294912  242294913
# 4     chr2   242294912  242294913    chr2  242294912  242294913
# 5    chr12    56435928   56435929   chr12   56435928   56435929
# 6    chr12    56435411   56435412   chr12   56435411   56435412
#
#           ge_source  regionID                  GWASLoci  index         rsid  \
# 0      B-cell_naive        52  chr2:241778007-242778547   3666  2:242294913
# 1     NK-cell_naive        52  chr2:241778007-242778547   3666  2:242294913
# 2    monocyte_naive        52  chr2:241778007-242778547   3666  2:242294913
# 3  CD4_T-cell_naive        52  chr2:241778007-242778547   3666  2:242294913
# 4  CD8_T-cell_naive        52  chr2:241778007-242778547   3666  2:242294913
# 5    monocyte_naive        26   chr12:55868078-57109885   1001  12:56435929
# 6    monocyte_naive        26   chr12:55868078-57109885   1262  12:56435412
#
#   chromosome   position allele1 allele2     maf    beta_x        se         z  \
# 0       chr2  242294913       G       A  0.0977 -0.066868  0.062422  -1.07122
# 1       chr2  242294913       G       A  0.0977 -0.066868  0.062422  -1.07122
# 2       chr2  242294913       G       A  0.0977 -0.066868  0.062422  -1.07122
# 3       chr2  242294913       G       A  0.0977 -0.066868  0.062422  -1.07122
# 4       chr2  242294913       G       A  0.0977 -0.066868  0.062422  -1.07122
# 5      chr12   56435929       G       C  0.4197 -0.246100  0.023800 -10.34030
# 6      chr12   56435412       A       G  0.3351  0.235300  0.024400   9.64344
#
#        prob   log10bf      mean        sd  mean_incl   sd_incl          pval  \
# 0  1.000000  13.63440 -0.334340  0.539277  -0.334340  0.539277  8.579658e-01
# 1  1.000000  13.63440 -0.334340  0.539277  -0.334340  0.539277  8.579658e-01
# 2  1.000000  13.63440 -0.334340  0.539277  -0.334340  0.539277  8.579658e-01
# 3  1.000000  13.63440 -0.334340  0.539277  -0.334340  0.539277  8.579658e-01
# 4  1.000000  13.63440 -0.334340  0.539277  -0.334340  0.539277  8.579658e-01
# 5  1.000000  11.42530  0.838226  2.396040   0.838226  2.396040  1.000000e+00
# 6  0.909011   4.14824  0.733566  2.274710   0.806994  2.373390  2.620026e-22
#
#             gwas_source  pieQTL.ID Chromosome  pieQTL.Position  \
# 0  T1D_34012112_Gaulton  rs3755397       chr2        242294913
# 1  T1D_34012112_Gaulton  rs3755397       chr2        242294913
# 2  T1D_34012112_Gaulton  rs3755397       chr2        242294913
# 3  T1D_34012112_Gaulton  rs3755397       chr2        242294913
# 4  T1D_34012112_Gaulton  rs3755397       chr2        242294913
# 5          T1D_32005708  rs1131017      chr12         56435929
# 6          T1D_32005708   rs705704      chr12         56435412
#
#         Target_geneID      Target_geneName        TSS        pvalue  \
# 0  ENSG00000168385.13  2020-09-02 00:00:00  242254515  1.700000e-09
# 1  ENSG00000168385.13  2020-09-02 00:00:00  242254515  2.140000e-07
# 2  ENSG00000168385.13  2020-09-02 00:00:00  242254515  1.830000e-11
# 3  ENSG00000168385.13  2020-09-02 00:00:00  242254515  1.160000e-12
# 4  ENSG00000168385.13  2020-09-02 00:00:00  242254515  9.460000e-13
# 5   ENSG00000139531.8                 SUOX   56390964  7.510000e-07
# 6   ENSG00000139531.8                 SUOX   56390964  3.210000e-06
#
#      FDR (DICE)  beta_y ref alt  Mean.TPM.Homozygous.Reference  \
# 0  7.490000e-06    1.17   A   G                         129.61
# 1  7.166490e-04    1.03   A   G                         175.26
# 2  1.630000e-07    1.28   A   G                         144.53
# 3  1.210000e-08    1.35   A   G                         133.93
# 4  8.650000e-09    1.33   A   G                         130.83
# 5  1.200625e-03    0.75   C   G                           6.69
# 6  3.980193e-03   -0.81   G   A                           9.04
#
#    Mean.TPM.Heterozygous  Mean.TPM.Homozygous.Alternative Interaction_type  \
# 0                 160.13                           210.54    Direct_pieQTL
# 1                 211.63                           229.33    Direct_pieQTL
# 2                 187.66                           224.97    Direct_pieQTL
# 3                 197.27                           244.58    Direct_pieQTL
# 4                 183.62                           225.51    Direct_pieQTL
# 5                   8.12                             9.20  Indirect_pieQTL
# 6                   7.69                             7.15  Indirect_pieQTL
#
#                                           GWAS.Trait             cline  \
# 0                  Leukemia  chronic lymphocytic          B-cell_naive
# 1                   Leukemia  chronic lymphocytic        NK-cell_naive
# 2                   Leukemia  chronic lymphocytic       monocyte_naive
# 3                   Leukemia  chronic lymphocytic     CD4_T-cell_naive
# 4                   Leukemia  chronic lymphocytic     CD8_T-cell_naive
# 5  Alopecia areata|Ankylosing spondylitis|Asthma|...    monocyte_naive
# 6  Alopecia areata|Ankylosing spondylitis|Asthma|...    monocyte_naive
#
#             geneid genename
# 0  ENSG00000168385    SEPT2
# 1  ENSG00000168385    SEPT2
# 2  ENSG00000168385    SEPT2
# 3  ENSG00000168385    SEPT2
# 4  ENSG00000168385    SEPT2
# 5  ENSG00000139531     SUOX
# 6  ENSG00000139531     SUOX

# %% [markdown]
# ## Slop Version

# %%
intersect_pbt = gwas_pbt.slop(b=10, g=genome_sizes).intersect(pieqtl_pbt, wa=True, wb=True)
intersect_df = intersect_pbt.to_dataframe()
intersect_df.columns = ['gwas_chr', 'gwas_start', 'gwas_end',
                       'pie_chr', 'pie_start', 'pie_end', 'ge_source']
intersect_df = intersect_df.merge(gwas_df, left_on=['gwas_chr', 'gwas_end'],
                                  right_on=['chromosome', 'position'],
                                  how='left')
intersect_df = intersect_df.merge(pieqtl_df, left_on=['pie_chr', 'pie_end', 'ge_source'],
                                  right_on=['Chromosome', 'pieQTL.Position', 'cline'],
                                  how='left')

# %%
intersect_df.loc[:, 'geneid'] = intersect_df['Target_geneID'].str.replace('\.[0-9]*', '', regex=True)
intersect_df.loc[:, 'genename'] = [gencode_dict[x] for x in intersect_df.loc[:, 'geneid'].values.tolist()]

# %%
intersect_df
# Out:
#    gwas_chr  gwas_start   gwas_end pie_chr  pie_start    pie_end  \
# 0      chr2   242294902  242294923    chr2  242294912  242294913
# 1      chr2   242294902  242294923    chr2  242294912  242294913
# 2      chr2   242294902  242294923    chr2  242294912  242294913
# 3      chr2   242294902  242294923    chr2  242294912  242294913
# 4      chr2   242294902  242294923    chr2  242294912  242294913
# 5     chr11   108031284  108031305   chr11  108031293  108031294
# 6     chr11   108031284  108031305   chr11  108031293  108031294
# 7     chr11   108031284  108031305   chr11  108031293  108031294
# 8     chr11   108031284  108031305   chr11  108031293  108031294
# 9     chr11   108031284  108031305   chr11  108031293  108031294
# 10    chr12    56435918   56435939   chr12   56435928   56435929
# 11    chr12    56435401   56435422   chr12   56435411   56435412
#
#            ge_source  regionID GWASLoci  index rsid chromosome  position  \
# 0       B-cell_naive       NaN      NaN    NaN  NaN        NaN       NaN
# 1      NK-cell_naive       NaN      NaN    NaN  NaN        NaN       NaN
# 2     monocyte_naive       NaN      NaN    NaN  NaN        NaN       NaN
# 3   CD4_T-cell_naive       NaN      NaN    NaN  NaN        NaN       NaN
# 4   CD8_T-cell_naive       NaN      NaN    NaN  NaN        NaN       NaN
# 5       B-cell_naive       NaN      NaN    NaN  NaN        NaN       NaN
# 6   CD4_T-cell_naive       NaN      NaN    NaN  NaN        NaN       NaN
# 7   CD4_T-cell_naive       NaN      NaN    NaN  NaN        NaN       NaN
# 8   CD4_T-cell_naive       NaN      NaN    NaN  NaN        NaN       NaN
# 9   CD4_T-cell_naive       NaN      NaN    NaN  NaN        NaN       NaN
# 10    monocyte_naive       NaN      NaN    NaN  NaN        NaN       NaN
# 11    monocyte_naive       NaN      NaN    NaN  NaN        NaN       NaN
#
#    allele1 allele2  maf  beta_x  se   z  prob  log10bf  mean  sd  mean_incl  \
# 0      NaN     NaN  NaN     NaN NaN NaN   NaN      NaN   NaN NaN        NaN
# 1      NaN     NaN  NaN     NaN NaN NaN   NaN      NaN   NaN NaN        NaN
# 2      NaN     NaN  NaN     NaN NaN NaN   NaN      NaN   NaN NaN        NaN
# 3      NaN     NaN  NaN     NaN NaN NaN   NaN      NaN   NaN NaN        NaN
# 4      NaN     NaN  NaN     NaN NaN NaN   NaN      NaN   NaN NaN        NaN
# 5      NaN     NaN  NaN     NaN NaN NaN   NaN      NaN   NaN NaN        NaN
# 6      NaN     NaN  NaN     NaN NaN NaN   NaN      NaN   NaN NaN        NaN
# 7      NaN     NaN  NaN     NaN NaN NaN   NaN      NaN   NaN NaN        NaN
# 8      NaN     NaN  NaN     NaN NaN NaN   NaN      NaN   NaN NaN        NaN
# 9      NaN     NaN  NaN     NaN NaN NaN   NaN      NaN   NaN NaN        NaN
# 10     NaN     NaN  NaN     NaN NaN NaN   NaN      NaN   NaN NaN        NaN
# 11     NaN     NaN  NaN     NaN NaN NaN   NaN      NaN   NaN NaN        NaN
#
#     sd_incl  pval gwas_source    pieQTL.ID Chromosome  pieQTL.Position  \
# 0       NaN   NaN         NaN    rs3755397       chr2        242294913
# 1       NaN   NaN         NaN    rs3755397       chr2        242294913
# 2       NaN   NaN         NaN    rs3755397       chr2        242294913
# 3       NaN   NaN         NaN    rs3755397       chr2        242294913
# 4       NaN   NaN         NaN    rs3755397       chr2        242294913
# 5       NaN   NaN         NaN  rs113714417      chr11        108031294
# 6       NaN   NaN         NaN  rs113714417      chr11        108031294
# 7       NaN   NaN         NaN  rs113714417      chr11        108031294
# 8       NaN   NaN         NaN  rs113714417      chr11        108031294
# 9       NaN   NaN         NaN  rs113714417      chr11        108031294
# 10      NaN   NaN         NaN    rs1131017      chr12         56435929
# 11      NaN   NaN         NaN     rs705704      chr12         56435412
#
#          Target_geneID      Target_geneName        TSS        pvalue  \
# 0   ENSG00000168385.13  2020-09-02 00:00:00  242254515  1.700000e-09
# 1   ENSG00000168385.13  2020-09-02 00:00:00  242254515  2.140000e-07
# 2   ENSG00000168385.13  2020-09-02 00:00:00  242254515  1.830000e-11
# 3   ENSG00000168385.13  2020-09-02 00:00:00  242254515  1.160000e-12
# 4   ENSG00000168385.13  2020-09-02 00:00:00  242254515  9.460000e-13
# 5   ENSG00000149311.13                  ATM  108093211  3.690000e-07
# 6   ENSG00000149308.12                 NPAT  108093369  4.130000e-09
# 7   ENSG00000149311.13                  ATM  108093211  4.340000e-09
# 8   ENSG00000149308.12                 NPAT  108093369  4.130000e-09
# 9   ENSG00000149311.13                  ATM  108093211  4.340000e-09
# 10   ENSG00000139531.8                 SUOX   56390964  7.510000e-07
# 11   ENSG00000139531.8                 SUOX   56390964  3.210000e-06
#
#       FDR (DICE)  beta_y ref alt  Mean.TPM.Homozygous.Reference  \
# 0   7.490000e-06    1.17   A   G                         129.61
# 1   7.166490e-04    1.03   A   G                         175.26
# 2   1.630000e-07    1.28   A   G                         144.53
# 3   1.210000e-08    1.35   A   G                         133.93
# 4   8.650000e-09    1.33   A   G                         130.83
# 5   1.059554e-03    0.72  TC   T                         110.56
# 6   1.610000e-05    0.83  TC   T                          55.60
# 7   1.680000e-05    0.83  TC   T                         207.25
# 8   1.610000e-05    0.83  TC   T                          55.60
# 9   1.680000e-05    0.83  TC   T                         207.25
# 10  1.200625e-03    0.75   C   G                           6.69
# 11  3.980193e-03   -0.81   G   A                           9.04
#
#     Mean.TPM.Heterozygous  Mean.TPM.Homozygous.Alternative Interaction_type  \
# 0                  160.13                           210.54    Direct_pieQTL
# 1                  211.63                           229.33    Direct_pieQTL
# 2                  187.66                           224.97    Direct_pieQTL
# 3                  197.27                           244.58    Direct_pieQTL
# 4                  183.62                           225.51    Direct_pieQTL
# 5                  129.86                           137.80    Direct_pieQTL
# 6                   64.65                            71.83    Direct_pieQTL
# 7                  227.69                           262.77    Direct_pieQTL
# 8                   64.65                            71.83    Direct_pieQTL
# 9                  227.69                           262.77    Direct_pieQTL
# 10                   8.12                             9.20  Indirect_pieQTL
# 11                   7.69                             7.15  Indirect_pieQTL
#
#                                            GWAS.Trait             cline  \
# 0                   Leukemia  chronic lymphocytic          B-cell_naive
# 1                    Leukemia  chronic lymphocytic        NK-cell_naive
# 2                    Leukemia  chronic lymphocytic       monocyte_naive
# 3                    Leukemia  chronic lymphocytic     CD4_T-cell_naive
# 4                    Leukemia  chronic lymphocytic     CD8_T-cell_naive
# 5                                                          B-cell_naive
# 6                                                      CD4_T-cell_naive
# 7                                                      CD4_T-cell_naive
# 8                                                      CD4_T-cell_naive
# 9                                                      CD4_T-cell_naive
# 10  Alopecia areata|Ankylosing spondylitis|Asthma|...    monocyte_naive
# 11  Alopecia areata|Ankylosing spondylitis|Asthma|...    monocyte_naive
#
#              geneid genename
# 0   ENSG00000168385    SEPT2
# 1   ENSG00000168385    SEPT2
# 2   ENSG00000168385    SEPT2
# 3   ENSG00000168385    SEPT2
# 4   ENSG00000168385    SEPT2
# 5   ENSG00000149311      ATM
# 6   ENSG00000149308     NPAT
# 7   ENSG00000149311      ATM
# 8   ENSG00000149308     NPAT
# 9   ENSG00000149311      ATM
# 10  ENSG00000139531     SUOX
# 11  ENSG00000139531     SUOX

# %%
intersect_df.shape
