# %%
import os 
import subprocess as sp
import numpy as np
import pandas as pd
import glob 
import seaborn as sns 
import matplotlib.pyplot as plt 

pd.set_option('display.max_rows', 500)

os.chdir('/mnt/BioHome/jreyna/jreyna/projects/dchallenge/')

outdir = 'results/notebooks/eqtl_report/'
os.makedirs(outdir, exist_ok=True)

# %%
# load eqtl samplesheet
eqtl_samplesheet = pd.read_table('config/eqtl_samplesheets/eqtl.t1d_only.txt')
eqtl_samplesheet.loc[:, 'qarray_id'] = np.arange(2, eqtl_samplesheet.shape[0] + 2)

# %%
eqtl_samplesheet
# Out:
#              eqtl_db               eqtl_origin  qarray_id
# 0          BLUEPRINT                  monocyte          2
# 1          BLUEPRINT                neutrophil          3
# 2          BLUEPRINT                    T-cell          4
# 3            GENCORD                       LCL          5
# 4            GENCORD                    T-cell          6
# 5               GTEx                     blood          7
# 6               GTEx                       LCL          8
# 7               GTEx                  pancreas          9
# 8         Lepik_2017                     blood         10
# 9         Quach_2016              monocyte_IAV         11
# 10        Quach_2016              monocyte_LPS         12
# 11        Quach_2016            monocyte_naive         13
# 12        Quach_2016         monocyte_Pam3CSK4         14
# 13        Quach_2016             monocyte_R848         15
# 14    Schmiedel_2018              B-cell_naive         16
# 15    Schmiedel_2018  CD4_T-cell_anti-CD3-CD28         17
# 16    Schmiedel_2018          CD4_T-cell_naive         18
# 17    Schmiedel_2018  CD8_T-cell_anti-CD3-CD28         19
# 18    Schmiedel_2018          CD8_T-cell_naive         20
# 19    Schmiedel_2018       monocyte_CD16_naive         21
# 20    Schmiedel_2018            monocyte_naive         22
# 21    Schmiedel_2018             NK-cell_naive         23
# 22    Schmiedel_2018                Tfh_memory         24
# 23    Schmiedel_2018             Th1-17_memory         25
# 24    Schmiedel_2018               Th17_memory         26
# 25    Schmiedel_2018                Th1_memory         27
# 26    Schmiedel_2018                Th2_memory         28
# 27    Schmiedel_2018               Treg_memory         29
# 28    Schmiedel_2018                Treg_naive         30
# 29  van_de_Bunt_2015          pancreatic_islet         31
# 30         ImmuNexUT                CD16p_Mono         32
# 31         ImmuNexUT                   CL_Mono         33
# 32         ImmuNexUT                    CM_CD8         34
# 33         ImmuNexUT                      DN_B         35
# 34         ImmuNexUT                    EM_CD8         36
# 35         ImmuNexUT               Fr_II_eTreg         37
# 36         ImmuNexUT                  Fr_III_T         38
# 37         ImmuNexUT                Fr_I_nTreg         39
# 38         ImmuNexUT                  Int_Mono         40
# 39         ImmuNexUT                       LDG         41
# 40         ImmuNexUT                       mDC         42
# 41         ImmuNexUT                   Mem_CD4         43
# 42         ImmuNexUT                   Mem_CD8         44
# 43         ImmuNexUT                   Naive_B         45
# 44         ImmuNexUT                 Naive_CD4         46
# 45         ImmuNexUT                 Naive_CD8         47
# 46         ImmuNexUT                   NC_Mono         48
# 47         ImmuNexUT                       Neu         49
# 48         ImmuNexUT                        NK         50
# 49         ImmuNexUT                       pDC         51
# 50         ImmuNexUT               Plasmablast         52
# 51         ImmuNexUT                      SM_B         53
# 52         ImmuNexUT                 TEMRA_CD8         54
# 53         ImmuNexUT                       Tfh         55
# 54         ImmuNexUT                      Th17         56
# 55         ImmuNexUT                       Th1         57
# 56         ImmuNexUT                       Th2         58
# 57         ImmuNexUT                     USM_B         59

# %% [markdown]
# ## Number of eQTL before filtering (eQTL Catalog)

# %%
before_data = []
before_glob = 'results/main/eqtl/*/ge/*_ge_*.all.prefilter.num_eqtls.txt'
before_glob = glob.glob(before_glob)

# %%
before_data = []
for fn in before_glob:
    with open(fn) as fr:
        
        eqtl, ge = os.path.basename(fn).split('_ge_')
        ge = ge.split('.')[0]
        
        num_eqtls = int(fr.read().strip())
        
        before_data.append([eqtl, ge, num_eqtls])

# %%
before_df = pd.DataFrame(before_data)
before_df.columns = ['eqtl', 'ge', 'num_eqtls_pre']

# %% [markdown]
# ## Number of eQTL post filtering (eQTL Catalog)

# %%
post_data = []
post_glob = 'results/main/eqtl/*/ge/*_ge_*.all.postfilter.num_eqtls.txt'
post_glob = glob.glob(post_glob)

# %%
post_data = []
for fn in post_glob:
    with open(fn) as fr:
        
        eqtl, ge = os.path.basename(fn).split('_ge_')
        ge = ge.split('.')[0]
        
        
        value = fr.read().strip()
        
        if value != '':
            num_eqtls = int(value)
        else:
            num_eqtls = 0        
        
        post_data.append([eqtl, ge, num_eqtls])

# %%
post_df = pd.DataFrame(post_data)
post_df.columns = ['eqtl', 'ge', 'num_eqtls_post']

# %%
post_df
# Out:
#                  eqtl                               ge  num_eqtls_post
# 0                GTEx               brain_hypothalamus          423929
# 1                GTEx                    brain_putamen          559636
# 2                GTEx                  artery_coronary          551959
# 3                GTEx                    kidney_cortex          123311
# 4                GTEx             heart_left_ventricle         1091506
# 5                GTEx                    esophagus_gej         1093510
# 6                GTEx                         pancreas         1063897
# 7                GTEx             skin_not_sun_exposed         1664368
# 8                GTEx                        pituitary          894226
# 9                GTEx  brain_anterior_cingulate_cortex          458124
# 10               GTEx                             lung         1521353
# 11               GTEx                            liver          505211
# 12               GTEx                           uterus          301774
# 13               GTEx                    artery_tibial         1903782
# 14               GTEx                          stomach          869131
# 15               GTEx                           testis         2218588
# 16               GTEx                  small_intestine          546703
# 17               GTEx                     nerve_tibial         2458457
# 18               GTEx                brain_spinal_cord          396491
# 19               GTEx                         prostate          633675
# 20               GTEx             minor_salivary_gland          388546
# 21               GTEx                            blood         1515737
# 22               GTEx                 esophagus_mucosa         1706880
# 23               GTEx                 colon_transverse         1147373
# 24               GTEx           heart_atrial_appendage         1154695
# 25               GTEx             esophagus_muscularis         1697245
# 26               GTEx             brain_frontal_cortex          548608
# 27               GTEx          brain_nucleus_accumbens          694671
# 28               GTEx                 adipose_visceral         1299706
# 29               GTEx                    brain_caudate          696488
# 30               GTEx                 skin_sun_exposed         2017018
# 31               GTEx                    adrenal_gland          782838
# 32               GTEx                            ovary          449356
# 33               GTEx           brain_substantia_nigra          260585
# 34               GTEx                       fibroblast         1870482
# 35               GTEx                   brain_amygdala          311365
# 36               GTEx                           spleen          999133
# 37               GTEx                           vagina          303041
# 38               GTEx             adipose_subcutaneous         1946741
# 39               GTEx                           muscle         1672825
# 40               GTEx                          thyroid         2559921
# 41               GTEx                    colon_sigmoid          996647
# 42               GTEx                     artery_aorta         1388992
# 43               GTEx                              LCL          431998
# 44               GTEx                     brain_cortex          829362
# 45               GTEx                 brain_cerebellum         1347204
# 46               GTEx                brain_hippocampus          392064
# 47               GTEx      brain_cerebellar_hemisphere         1009934
# 48               GTEx                           breast         1122669
# 49         Lepik_2017                            blood         2946020
# 50         Quach_2016                   monocyte_naive         1293710
# 51         Quach_2016                    monocyte_R848         1047996
# 52         Quach_2016                     monocyte_LPS         1101435
# 53         Quach_2016                monocyte_Pam3CSK4         1177094
# 54         Quach_2016                     monocyte_IAV         1049180
# 55          BLUEPRINT                           T-cell         1818085
# 56          BLUEPRINT                         monocyte         2213353
# 57          BLUEPRINT                       neutrophil         1838013
# 58     Schmiedel_2018                      Th17_memory          701417
# 59     Schmiedel_2018                       Th1_memory          513914
# 60     Schmiedel_2018                     B-cell_naive          633355
# 61     Schmiedel_2018                 CD8_T-cell_naive          706670
# 62     Schmiedel_2018                      Treg_memory          588584
# 63     Schmiedel_2018         CD8_T-cell_anti-CD3-CD28          510059
# 64     Schmiedel_2018                       Th2_memory          615587
# 65     Schmiedel_2018                       Treg_naive          623104
# 66     Schmiedel_2018         CD4_T-cell_anti-CD3-CD28          518618
# 67     Schmiedel_2018                 CD4_T-cell_naive          669339
# 68     Schmiedel_2018                       Tfh_memory          603596
# 69     Schmiedel_2018                    Th1-17_memory          636433
# 70     Schmiedel_2018                   monocyte_naive          643412
# 71     Schmiedel_2018              monocyte_CD16_naive          614987
# 72     Schmiedel_2018                    NK-cell_naive          472002
# 73            GENCORD                              LCL          823148
# 74            GENCORD                       fibroblast          575290
# 75            GENCORD                           T-cell          716949
# 76   van_de_Bunt_2015                 pancreatic_islet          178434
# 77          ImmuNexUT                              LDG          683318
# 78          ImmuNexUT                              Tfh         1921385
# 79          ImmuNexUT                        Naive_CD8         1819410
# 80          ImmuNexUT                       CD16p_Mono         2192186
# 81          ImmuNexUT                              Th1         1716189
# 82          ImmuNexUT                              mDC         2060272
# 83          ImmuNexUT                        Naive_CD4         1825365
# 84          ImmuNexUT                            USM_B         1711569
# 85          ImmuNexUT                         Int_Mono         1512639
# 86          ImmuNexUT                              Th2         1726544
# 87          ImmuNexUT                              pDC         2078397
# 88          ImmuNexUT                              Neu         2061244
# 89          ImmuNexUT                           CM_CD8         1173528
# 90          ImmuNexUT                           EM_CD8         1421779
# 91          ImmuNexUT                             DN_B         1680321
# 92          ImmuNexUT                        TEMRA_CD8         1351265
# 93          ImmuNexUT                          NC_Mono         1587733
# 94          ImmuNexUT                      Fr_II_eTreg         1672923
# 95          ImmuNexUT                          Mem_CD4         1859035
# 96          ImmuNexUT                         Fr_III_T         1458861
# 97          ImmuNexUT                          CL_Mono         2232482
# 98          ImmuNexUT                               NK         1726682
# 99          ImmuNexUT                      Plasmablast         1701243
# 100         ImmuNexUT                             SM_B         1964129
# 101         ImmuNexUT                          Mem_CD8         1702537
# 102         ImmuNexUT                       Fr_I_nTreg         1114054
# 103         ImmuNexUT                             Th17         1878419
# 104         ImmuNexUT                          Naive_B         1795710

# %% [markdown]
# ## Compare the eQTL data  before and after FDR filtering

# %%
all_df = pd.merge(before_df, post_df, on=['eqtl', 'ge'], how='outer')
all_df['%Post'] = all_df['num_eqtls_post'] / all_df['num_eqtls_pre'] * 100

# adding the qsub array id 
all_df = all_df.merge(eqtl_samplesheet, left_on=['eqtl', 'ge'], right_on=['eqtl_db', 'eqtl_origin'])

# %%
pd.set_option('display.max_rows', 100) 
display(all_df)
pd.set_option('display.max_rows', 20)
# Out:
#                 eqtl                        ge  num_eqtls_pre  num_eqtls_post  \
# 0               GTEx                     blood      117815659         1515737
# 1               GTEx                       LCL      134305450          431998
# 2               GTEx                  pancreas      134927983         1063897
# 3         Lepik_2017                     blood      103124065         2946020
# 4         Quach_2016             monocyte_R848      168940282         1047996
# 5         Quach_2016         monocyte_Pam3CSK4      171429490         1177094
# 6         Quach_2016              monocyte_IAV      188522612         1049180
# 7         Quach_2016            monocyte_naive      177145991         1293710
# 8         Quach_2016              monocyte_LPS      169199423         1101435
# 9          BLUEPRINT                  monocyte      107504217         2213353
# 10         BLUEPRINT                    T-cell      114006812         1818085
# 11         BLUEPRINT                neutrophil       86606708         1838013
# 12    Schmiedel_2018               Treg_memory      155297785          588584
# 13    Schmiedel_2018            monocyte_naive      138656372          643412
# 14    Schmiedel_2018                Treg_naive      156779364          623104
# 15    Schmiedel_2018       monocyte_CD16_naive      139733495          614987
# 16    Schmiedel_2018                Tfh_memory      155294143          603596
# 17    Schmiedel_2018             NK-cell_naive      156385911          472002
# 18    Schmiedel_2018          CD8_T-cell_naive      155723260          706670
# 19    Schmiedel_2018               Th17_memory      151190959          701417
# 20    Schmiedel_2018              B-cell_naive      154773799          633355
# 21    Schmiedel_2018                Th1_memory      153424768          513914
# 22    Schmiedel_2018          CD4_T-cell_naive      154286630          669339
# 23    Schmiedel_2018             Th1-17_memory      150672748          636433
# 24    Schmiedel_2018  CD4_T-cell_anti-CD3-CD28      141385943          518618
# 25    Schmiedel_2018                Th2_memory      154397233          615587
# 26    Schmiedel_2018  CD8_T-cell_anti-CD3-CD28      141347873          510059
# 27           GENCORD                       LCL      142098342          823148
# 28           GENCORD                    T-cell      155301586          716949
# 29  van_de_Bunt_2015          pancreatic_islet      180559672          178434
# 30         ImmuNexUT                 Naive_CD4       92372864         1825365
# 31         ImmuNexUT                Fr_I_nTreg       93685756         1114054
# 32         ImmuNexUT                      Th17       90281646         1878419
# 33         ImmuNexUT                 Naive_CD8       92670192         1819410
# 34         ImmuNexUT               Plasmablast       75710636         1701243
# 35         ImmuNexUT                CD16p_Mono       80908459         2192186
# 36         ImmuNexUT                   Mem_CD8       90704679         1702537
# 37         ImmuNexUT                    EM_CD8       90485610         1421779
# 38         ImmuNexUT                   Mem_CD4       91503125         1859035
# 39         ImmuNexUT               Fr_II_eTreg       88794440         1672923
# 40         ImmuNexUT                  Int_Mono       80642976         1512639
# 41         ImmuNexUT                 TEMRA_CD8       88023558         1351265
# 42         ImmuNexUT                       pDC       85996889         2078397
# 43         ImmuNexUT                     USM_B       90812282         1711569
# 44         ImmuNexUT                       Th2       91144835         1726544
# 45         ImmuNexUT                   Naive_B       91558846         1795710
# 46         ImmuNexUT                      SM_B       90807380         1964129
# 47         ImmuNexUT                       LDG       78916242          683318
# 48         ImmuNexUT                   CL_Mono       82522748         2232482
# 49         ImmuNexUT                       Neu       71421150         2061244
# 50         ImmuNexUT                      DN_B       91481775         1680321
# 51         ImmuNexUT                       Th1       90175393         1716189
# 52         ImmuNexUT                  Fr_III_T       91075680         1458861
# 53         ImmuNexUT                    CM_CD8       90962444         1173528
# 54         ImmuNexUT                       mDC       84779396         2060272
# 55         ImmuNexUT                   NC_Mono       80626490         1587733
# 56         ImmuNexUT                        NK       88189090         1726682
# 57         ImmuNexUT                       Tfh       91352934         1921385
#
#        %Post           eqtl_db               eqtl_origin  qarray_id
# 0   1.286533              GTEx                     blood          7
# 1   0.321653              GTEx                       LCL          8
# 2   0.788492              GTEx                  pancreas          9
# 3   2.856773        Lepik_2017                     blood         10
# 4   0.620335        Quach_2016             monocyte_R848         15
# 5   0.686634        Quach_2016         monocyte_Pam3CSK4         14
# 6   0.556527        Quach_2016              monocyte_IAV         11
# 7   0.730307        Quach_2016            monocyte_naive         13
# 8   0.650969        Quach_2016              monocyte_LPS         12
# 9   2.058852         BLUEPRINT                  monocyte          2
# 10  1.594716         BLUEPRINT                    T-cell          4
# 11  2.122252         BLUEPRINT                neutrophil          3
# 12  0.379003    Schmiedel_2018               Treg_memory         29
# 13  0.464033    Schmiedel_2018            monocyte_naive         22
# 14  0.397440    Schmiedel_2018                Treg_naive         30
# 15  0.440114    Schmiedel_2018       monocyte_CD16_naive         21
# 16  0.388679    Schmiedel_2018                Tfh_memory         24
# 17  0.301819    Schmiedel_2018             NK-cell_naive         23
# 18  0.453799    Schmiedel_2018          CD8_T-cell_naive         20
# 19  0.463928    Schmiedel_2018               Th17_memory         26
# 20  0.409213    Schmiedel_2018              B-cell_naive         16
# 21  0.334962    Schmiedel_2018                Th1_memory         27
# 22  0.433828    Schmiedel_2018          CD4_T-cell_naive         18
# 23  0.422394    Schmiedel_2018             Th1-17_memory         25
# 24  0.366810    Schmiedel_2018  CD4_T-cell_anti-CD3-CD28         17
# 25  0.398703    Schmiedel_2018                Th2_memory         28
# 26  0.360854    Schmiedel_2018  CD8_T-cell_anti-CD3-CD28         19
# 27  0.579281           GENCORD                       LCL          5
# 28  0.461650           GENCORD                    T-cell          6
# 29  0.098823  van_de_Bunt_2015          pancreatic_islet         31
# 30  1.976084         ImmuNexUT                 Naive_CD4         46
# 31  1.189139         ImmuNexUT                Fr_I_nTreg         39
# 32  2.080621         ImmuNexUT                      Th17         56
# 33  1.963317         ImmuNexUT                 Naive_CD8         47
# 34  2.247033         ImmuNexUT               Plasmablast         52
# 35  2.709465         ImmuNexUT                CD16p_Mono         32
# 36  1.877011         ImmuNexUT                   Mem_CD8         44
# 37  1.571276         ImmuNexUT                    EM_CD8         36
# 38  2.031663         ImmuNexUT                   Mem_CD4         43
# 39  1.884040         ImmuNexUT               Fr_II_eTreg         37
# 40  1.875723         ImmuNexUT                  Int_Mono         40
# 41  1.535117         ImmuNexUT                 TEMRA_CD8         54
# 42  2.416828         ImmuNexUT                       pDC         51
# 43  1.884733         ImmuNexUT                     USM_B         59
# 44  1.894286         ImmuNexUT                       Th2         58
# 45  1.961263         ImmuNexUT                   Naive_B         45
# 46  2.162962         ImmuNexUT                      SM_B         53
# 47  0.865878         ImmuNexUT                       LDG         41
# 48  2.705293         ImmuNexUT                   CL_Mono         33
# 49  2.886041         ImmuNexUT                       Neu         49
# 50  1.836782         ImmuNexUT                      DN_B         35
# 51  1.903168         ImmuNexUT                       Th1         57
# 52  1.601812         ImmuNexUT                  Fr_III_T         38
# 53  1.290124         ImmuNexUT                    CM_CD8         34
# 54  2.430156         ImmuNexUT                       mDC         42
# 55  1.969245         ImmuNexUT                   NC_Mono         48
# 56  1.957932         ImmuNexUT                        NK         50
# 57  2.103255         ImmuNexUT                       Tfh         55

# %%
t1d_related = pd.read_table('config/eqtl_samplesheets/eqtl.samplesheet.tsv')
t1d_related_eqtls = [['BLUEPRINT', 'monocyte'],
     ['BLUEPRINT', 'neutrophil'],
     ['BLUEPRINT', 'T-cell'],
     ['GENCORD', 'LCL'],
     ['GENCORD', 'T-cell'],
     ['GTEx', 'blood'],
     ['GTEx', 'LCL'],
     ['GTEx', 'liver'],
     ['GTEx', 'pancreas'],
     ['Lepik_2017', 'blood'],
     ['Quach_2016', 'monocyte_IAV'],
     ['Quach_2016', 'monocyte_LPS'],
     ['Quach_2016', 'monocyte_naive'],
     ['Quach_2016', 'monocyte_Pam3CSK4'],
     ['Quach_2016', 'monocyte_R848'],
     ['Schmiedel_2018', 'B-cell_naive'],
     ['Schmiedel_2018', 'CD4_T-cell_anti-CD3-CD28'],
     ['Schmiedel_2018', 'CD4_T-cell_naive'],
     ['Schmiedel_2018', 'CD8_T-cell_anti-CD3-CD28'],
     ['Schmiedel_2018', 'CD8_T-cell_naive'],
     ['Schmiedel_2018', 'monocyte_CD16_naive'],
     ['Schmiedel_2018', 'monocyte_naive'],
     ['Schmiedel_2018', 'NK-cell_naive'],
     ['Schmiedel_2018', 'Tfh_memory'],
     ['Schmiedel_2018', 'Th1-17_memory'],
     ['Schmiedel_2018', 'Th17_memory'],
     ['Schmiedel_2018', 'Th1_memory'],
     ['Schmiedel_2018', 'Th2_memory'],
     ['Schmiedel_2018', 'Treg_memory'],
     ['Schmiedel_2018', 'Treg_naive'],
     ['van_de_Bunt_2015', 'pancreatic_islet'],
     ['ImmuNexUT', 'CD16p_Mono'],
     ['ImmuNexUT', 'CL_Mono'],
     ['ImmuNexUT', 'CM_CD8'],
     ['ImmuNexUT', 'DN_B'],
     ['ImmuNexUT', 'EM_CD8'],
     ['ImmuNexUT', 'Fr_II_eTreg'],
     ['ImmuNexUT', 'Fr_III_T'],
     ['ImmuNexUT', 'Fr_I_nTreg'],
     ['ImmuNexUT', 'Int_Mono'],
     ['ImmuNexUT', 'LDG'],
     ['ImmuNexUT', 'mDC'],
     ['ImmuNexUT', 'Mem_CD4'],
     ['ImmuNexUT', 'Mem_CD8'],
     ['ImmuNexUT', 'Naive_B'],
     ['ImmuNexUT', 'Naive_CD4'],
     ['ImmuNexUT', 'Naive_CD8'],
     ['ImmuNexUT', 'NC_Mono'],
     ['ImmuNexUT', 'Neu'],
     ['ImmuNexUT', 'NK'],
     ['ImmuNexUT', 'pDC'],
     ['ImmuNexUT', 'Plasmablast'],
     ['ImmuNexUT', 'SM_B'],
     ['ImmuNexUT', 'TEMRA_CD8'],
     ['ImmuNexUT', 'Tfh'],
     ['ImmuNexUT', 'Th17'],
     ['ImmuNexUT', 'Th1'],
     ['ImmuNexUT', 'Th2'],
     ['ImmuNexUT', 'USM_B']]

# %%
num_immunexut = len([x[0] for x in t1d_related_eqtls if x[0] == 'ImmuNexUT'])
curr_poss_eqtls = len(t1d_related_eqtls) - num_immunexut
print(curr_poss_eqtls)
# Out:
# 31

# %%
bools = []
for sr in all_df.iloc[:, [0,1]].values:
    if sr.tolist() in t1d_related_eqtls:
        bools.append(True)
    else:
        bools.append(False)

# %%
all_df = all_df.loc[bools]

# %%
all_df.shape
# Out:
# (58, 8)

# %%
post_eqtl_means = all_df.num_eqtls_post.mean()
print('Mean number of significant eQTLs: {:.1f}'.format(post_eqtl_means))
# Out:
# Mean number of significant eQTLs: 1308540.4

# %%
all_df
# Out:
#           eqtl             ge  num_eqtls_pre  num_eqtls_post     %Post  \
# 0         GTEx          blood      117815659         1515737  1.286533
# 1         GTEx            LCL      134305450          431998  0.321653
# 2         GTEx       pancreas      134927983         1063897  0.788492
# 3   Lepik_2017          blood      103124065         2946020  2.856773
# 4   Quach_2016  monocyte_R848      168940282         1047996  0.620335
# ..         ...            ...            ...             ...       ...
# 53   ImmuNexUT         CM_CD8       90962444         1173528  1.290124
# 54   ImmuNexUT            mDC       84779396         2060272  2.430156
# 55   ImmuNexUT        NC_Mono       80626490         1587733  1.969245
# 56   ImmuNexUT             NK       88189090         1726682  1.957932
# 57   ImmuNexUT            Tfh       91352934         1921385  2.103255
#
#        eqtl_db    eqtl_origin  qarray_id
# 0         GTEx          blood          7
# 1         GTEx            LCL          8
# 2         GTEx       pancreas          9
# 3   Lepik_2017          blood         10
# 4   Quach_2016  monocyte_R848         15
# ..         ...            ...        ...
# 53   ImmuNexUT         CM_CD8         34
# 54   ImmuNexUT            mDC         42
# 55   ImmuNexUT        NC_Mono         48
# 56   ImmuNexUT             NK         50
# 57   ImmuNexUT            Tfh         55
#
# [58 rows x 8 columns]

# %%
all_df.loc[(all_df.num_eqtls_pre == 0)].sort_values('qarray_id')
# Out:
# Empty DataFrame
# Columns: [eqtl, ge, num_eqtls_pre, num_eqtls_post, %Post, eqtl_db, eqtl_origin, qarray_id]
# Index: []

# %%
np.sum(all_df.num_eqtls_pre == 0)
# Out:
# 0

# %%
np.sum(all_df.num_eqtls_post == 0)
# Out:
# 0

# %% [markdown]
# #### Summary of min and max

# %%
all_df.iloc[all_df.num_eqtls_post.argmax()]
# Out:
# eqtl              Lepik_2017
# ge                     blood
# num_eqtls_pre      103124065
# num_eqtls_post       2946020
# %Post                2.85677
# eqtl_db           Lepik_2017
# eqtl_origin            blood
# qarray_id                 10
# Name: 3, dtype: object

# %%
all_df.iloc[all_df.num_eqtls_post.argmin()]
# Out:
# eqtl              van_de_Bunt_2015
# ge                pancreatic_islet
# num_eqtls_pre            180559672
# num_eqtls_post              178434
# %Post                    0.0988227
# eqtl_db           van_de_Bunt_2015
# eqtl_origin       pancreatic_islet
# qarray_id                       31
# Name: 29, dtype: object

# %% [markdown]
# ## Visualize eQTL Results

# %%
eqtl_colors ={'BLUEPRINT': (0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
             'GENCORD': (1.0, 0.4980392156862745, 0.054901960784313725),
             'GTEx': (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
             'ImmuNexUT': (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
             'Lepik_2017': (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
             'Quach_2016': (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
             'Schmiedel_2018': (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
             'van_de_Bunt_2015': (0.4980392156862745, 0.4980392156862745, 0.4980392156862745)}

# %%
plot_data
# Out:
#                 eqtl                ge  num_eqtls_pre  num_eqtls_post  \
# 11         BLUEPRINT        neutrophil       86606708         1838013
# 10         BLUEPRINT            T-cell      114006812         1818085
# 9          BLUEPRINT          monocyte      107504217         2213353
# 28           GENCORD            T-cell      155301586          716949
# 27           GENCORD               LCL      142098342          823148
# ..               ...               ...            ...             ...
# 20    Schmiedel_2018      B-cell_naive      154773799          633355
# 21    Schmiedel_2018        Th1_memory      153424768          513914
# 18    Schmiedel_2018  CD8_T-cell_naive      155723260          706670
# 16    Schmiedel_2018        Tfh_memory      155294143          603596
# 29  van_de_Bunt_2015  pancreatic_islet      180559672          178434
#
#        %Post           eqtl_db       eqtl_origin  qarray_id
# 11  2.122252         BLUEPRINT        neutrophil          3
# 10  1.594716         BLUEPRINT            T-cell          4
# 9   2.058852         BLUEPRINT          monocyte          2
# 28  0.461650           GENCORD            T-cell          6
# 27  0.579281           GENCORD               LCL          5
# ..       ...               ...               ...        ...
# 20  0.409213    Schmiedel_2018      B-cell_naive         16
# 21  0.334962    Schmiedel_2018        Th1_memory         27
# 18  0.453799    Schmiedel_2018  CD8_T-cell_naive         20
# 16  0.388679    Schmiedel_2018        Tfh_memory         24
# 29  0.098823  van_de_Bunt_2015  pancreatic_islet         31
#
# [58 rows x 8 columns]

# %%
fig, ax = plt.subplots(figsize=(4, 10))

# Draw a nested barplot by species and sex
plot_data = all_df.sort_values('eqtl')

g = sns.barplot(data=plot_data,   
            y="ge", x="num_eqtls_post",
            hue='eqtl', palette=eqtl_colors, orient='h', ax=ax)

# move the legend
ax.legend(bbox_to_anchor=(1.04,1), loc="upper left")

for x in g.get_xticklabels():
    x.set_rotation(90)

g.set_title('Number of Significant eQTLs')
g.set_ylabel('Sample (Source of gene expression)')
g.set_xlabel('Count')
# Out:
# Text(0.5, 0, 'Count')

# %% [markdown]
# ## Write the report

# %%
report_fn = os.path.join(outdir, 'eqtl_report.tsv')
all_df.to_csv(report_fn, sep='\t', index=False)
